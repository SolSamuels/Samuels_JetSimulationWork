# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

# %%
#JET RESEMBLENSE
cen = 250

ratio_data = np.array([["Dispersion Value", "Quad Value", "Hexa Value", "Hexa:Quad Ratio"]])

adder = 0
for dispersion in range(9):


    nx=500
    ny=500
    x=np.outer(np.linspace(-5,5,nx),np.ones(ny))
    y=np.outer(np.ones(nx),np.linspace(-5,5,ny))
    img=np.zeros((500, 500))
    
    x2=x-adder
    x3=x+adder
    r2=np.sqrt(x2**2 + y**2)
    r3=np.sqrt(x3**2 + y**2)
    re=np.sqrt(x**2 + y**2)


    img[re<0.5]=1

    img[r2<1.0]=1
    img[r3<1.0]=1

    plt.imshow(img)
    plt.show()





    # Quadruple moment:
    rsqr=x**2 + y**2
    q2=np.zeros([2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            q2[i,j]=1./2.*np.sum(img*(2*xy[i]*xy[j] - rsqr*dij))
    print("\n\nQuadrupol moment:\n\n",q2/np.sum(img))
    
    q2_norm = q2/np.sum(img)


    # Octupole moment:

    q3=np.zeros([2,2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            for k in [0,1]:
                if i==k:
                    dik=1
                else:
                    dik=0
                if j==k:
                    djk=1
                else:
                    djk=0
                q3[i,j,k]=1./2.*np.sum(img*(4*xy[i]*xy[j]*xy[k])) - np.sum(img*(rsqr*(xy[i]*djk + xy[j]*dik + xy[k]*dij)))
                
    q3_norm = q3/np.sum(img)
    print("\n\nOctupolpol moment:\n\n",q3_norm)
    
    
    

    # Hexadecapole moment:

    q4=np.zeros([2,2,2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            for k in [0,1]:
                if i==k:
                    dik=1
                else:
                    dik=0
                if j==k:
                    djk=1
                else:
                    djk=0
                for l in [0,1]:
                    if i==l:
                        dil=1
                    else:
                        dil=0
                    if j==l:
                        djl=1
                    else:
                        djl=0
                    if k==l:
                        dkl=1
                    else:
                        dkl=0
                    q4[i,j,k,l]=1./8.*np.sum(img*(24*xy[i]*xy[j]*xy[k]*xy[l] - 
                                           4*rsqr*(xy[k]*xy[l]*dij + xy[j]*xy[l]*dik + xy[j]*xy[k]*dil + xy[i]*xy[l]*djk + xy[i]*xy[k]*djl + xy[i]*xy[j]*dkl)) +
                                           img*(dij*dkl + dik*djl + dil*djk)*rsqr**2)

    print("\n\nHexadecapol moment:\n\n",q4/np.sum(img))
    q4_norm =q4/np.sum(img)
    
    quad_val = q2_norm[0,0]
    hexa_val = q4_norm[0,0,0,0]
    
    dis_data = np.array([adder, round(quad_val, 4), round(hexa_val, 4), round(hexa_val/quad_val, 4)])
    ratio_data = np.vstack([ratio_data, dis_data])

    print("\n\n")
    
    adder += 0.5
    
data_table = pd.DataFrame(ratio_data)
        
print(data_table)
# Out:
# Quadrupol moment:
#
#  [[-7.26897939e-18 -1.13134140e-18]
#  [-1.13134140e-18 -7.26897939e-18]]
#
#
# Octupolpol moment:
#
#  [[[2.94393665e-16 9.93433099e-17]
#   [9.95420711e-17 8.35932630e-17]]
#
#  [[9.95420711e-17 8.35932630e-17]
#   [8.35932630e-17 3.06395250e-16]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 3.55300938e-04 -3.49606675e-19]
#    [-2.16507687e-19 -3.55300938e-04]]
#
#   [[-4.13494189e-19 -3.55300938e-04]
#    [-3.55300938e-04 -1.05591864e-19]]]
#
#
#  [[[-4.13494189e-19 -3.55300938e-04]
#    [-3.55300938e-04 -1.05591864e-19]]
#
#   [[-3.55300938e-04  2.70634609e-19]
#    [ 2.13845707e-19  3.55300938e-04]]]]
# Quadrupol moment:
#
#  [[ 1.67834325e-01  1.19909729e-18]
#  [ 1.19909729e-18 -1.67834325e-01]]
#
#
# Octupolpol moment:
#
#  [[[5.77823826e-16 4.45605715e-17]
#   [4.44371350e-17 3.00197534e-16]]
#
#  [[4.44371350e-17 3.00197534e-16]
#   [3.00197534e-16 5.31394073e-16]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 2.72112387e-02 -2.99774324e-19]
#    [-1.37543513e-18 -2.72112387e-02]]
#
#   [[-4.05577026e-19 -2.72112387e-02]
#    [-2.72112387e-02 -3.26224999e-19]]]
#
#
#  [[[-5.29013512e-20 -2.72112387e-02]
#    [-2.72112387e-02 -2.55689864e-19]]
#
#   [[-2.72112387e-02  4.40844594e-20]
#    [-4.40844594e-20  2.72112387e-02]]]]
# Quadrupol moment:
#
#  [[ 4.92080727e-01 -4.69766267e-19]
#  [-4.69766267e-19 -4.92080727e-01]]
#
#
# Octupolpol moment:
#
#  [[[ 1.51926435e-15 -9.78303559e-17]
#   [-1.02645241e-16  8.20098178e-16]]
#
#  [[-1.02645241e-16  8.20098178e-16]
#   [ 8.20098178e-16  8.96716064e-16]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 3.69881165e-01  3.98557749e-18]
#    [ 1.30519790e-18 -3.69881165e-01]]
#
#   [[-1.18972462e-18 -3.69881165e-01]
#    [-3.69881165e-01 -2.11351080e-18]]]
#
#
#  [[[-5.94862311e-18 -3.69881165e-01]
#    [-3.69881165e-01 -2.78535529e-18]]
#
#   [[-3.69881165e-01 -3.96108316e-18]
#    [-3.16326782e-18  3.69881165e-01]]]]
# Quadrupol moment:
#
#  [[ 9.99832698e-01 -4.03259214e-19]
#  [-4.03259214e-19 -9.99832698e-01]]
#
#
# Octupolpol moment:
#
#  [[[-1.03234359e-15 -3.14138928e-16]
#   [-3.16558483e-16  1.54851538e-15]]
#
#  [[-3.16558483e-16  1.54851538e-15]
#   [ 1.61303686e-15  1.49634372e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 1.68816959e+00 -2.41955529e-18]
#    [ 6.45214743e-18 -1.68816959e+00]]
#
#   [[ 1.04847396e-17 -1.68816959e+00]
#    [-1.68816959e+00  1.61303686e-18]]]
#
#
#  [[[ 3.22607372e-18 -1.68816959e+00]
#    [-1.68816959e+00  1.61303686e-18]]
#
#   [[-1.68816959e+00  7.25866586e-18]
#    [-6.45214743e-18  1.68816959e+00]]]]
# Quadrupol moment:
#
#  [[ 1.77746527e+00  1.41674331e-18]
#  [ 1.41674331e-18 -1.77746527e+00]]
#
#
# Octupolpol moment:
#
#  [[[ 3.61074348e-15 -6.44687469e-16]
#   [-6.47709855e-16  1.32340196e-15]]
#
#  [[-6.47709855e-16  1.32340196e-15]
#   [ 1.32340196e-15  2.47007903e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 5.33358802e+00  4.40764586e-19]
#    [ 3.55759987e-17 -5.33358802e+00]]
#
#   [[ 7.56855760e-18 -5.33358802e+00]
#    [-5.33358802e+00 -4.92397008e-18]]]
#
#
#  [[[ 8.90344463e-18 -5.33358802e+00]
#    [-5.33358802e+00 -3.31203103e-18]]
#
#   [[-5.33358802e+00 -3.11053865e-18]
#    [-1.04650106e-17  5.33358802e+00]]]]
# Quadrupol moment:
#
#  [[ 2.77592055e+00 -2.82660664e-18]
#  [-2.82660664e-18 -2.77592055e+00]]
#
#
# Octupolpol moment:
#
#  [[[ 4.95637440e-15 -1.04413022e-15]
#   [-1.03253388e-15  5.37585921e-15]]
#
#  [[-1.03253388e-15  5.37585921e-15]
#   [ 5.37585921e-15  3.65414276e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 1.30121245e+01  2.77555756e-17]
#    [-1.24786648e-17 -1.30121245e+01]]
#
#   [[-2.99992143e-18 -1.30121245e+01]
#    [-1.30121245e+01 -2.92681410e-17]]]
#
#
#  [[[-9.05018315e-18 -1.30121245e+01]
#    [-1.30121245e+01 -1.63861255e-18]]
#
#   [[-1.30121245e+01 -2.30162039e-17]
#    [-1.39408114e-17  1.30121245e+01]]]]
# Quadrupol moment:
#
#  [[ 3.99781045e+00 -4.70892914e-18]
#  [-4.70892914e-18 -3.99781045e+00]]
#
#
# Octupolpol moment:
#
#  [[[ 1.34265627e-14 -1.51699381e-15]
#   [-1.49899020e-15  6.92710582e-15]]
#
#  [[-1.49899020e-15  6.92710582e-15]
#   [ 6.92710582e-15  5.15839705e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 2.69824196e+01 -4.09494025e-17]
#    [-6.63662730e-17 -2.69824196e+01]]
#
#   [[ 5.02285774e-17 -2.69824196e+01]
#    [-2.69824196e+01 -2.93504338e-17]]]
#
#
#  [[[ 6.43490611e-17 -2.69824196e+01]
#    [-2.69824196e+01 -2.95521550e-17]]
#
#   [[-2.69824196e+01 -1.68437197e-17]
#    [-6.74757396e-17  2.69824196e+01]]]]
# Quadrupol moment:
#
#  [[ 5.44256666e+00 -4.11425675e-18]
#  [-4.11425675e-18 -5.44256666e+00]]
#
#
# Octupolpol moment:
#
#  [[[-7.43456159e-15 -2.10987584e-15]
#   [-2.09585018e-15  3.40105379e-15]]
#
#  [[-2.09585018e-15  3.40105379e-15]
#   [ 3.40105379e-15  6.90749648e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 5.00079949e+01 -9.83976249e-17]
#    [-2.62969249e-17 -5.00079949e+01]]
#
#   [[ 3.82685947e-18 -5.00079949e+01]
#    [-5.00079949e+01 -1.36564496e-16]]]
#
#
#  [[[ 7.16402095e-17 -5.00079949e+01]
#    [-5.00079949e+01 -1.12464286e-16]]
#
#   [[-5.00079949e+01 -1.36464126e-16]
#    [-1.75585828e-16  5.00079949e+01]]]]
# Quadrupol moment:
#
#  [[ 7.10703159e+00 -1.00883510e-18]
#  [-1.00883510e-18 -7.10703159e+00]]
#
#
# Octupolpol moment:
#
#  [[[ 1.90080674e-14 -2.76501523e-15]
#   [-2.79406969e-15  1.03256290e-14]]
#
#  [[-2.79406969e-15  1.03256290e-14]
#   [ 1.03256290e-14  8.87194805e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 8.52622528e+01  1.42043982e-16]
#    [ 1.16217803e-16 -8.52622528e+01]]
#
#   [[ 7.74785355e-17 -8.52622528e+01]
#    [-8.52622528e+01  0.00000000e+00]]]
#
#
#  [[[ 9.03916247e-17 -8.52622528e+01]
#    [-8.52622528e+01  2.58261785e-17]]
#
#   [[-8.52622528e+01  3.87392677e-17]
#    [-2.58261785e-17  8.52622528e+01]]]]
#
#
#
#                   0           1           2                   3
# 0  Dispersion Value  Quad Value  Hexa Value     Hexa:Quad Ratio
# 1               0.0        -0.0      0.0004  -48879067943658.26
# 2               0.5      0.1678      0.0272              0.1621
# 3               1.0      0.4921      0.3699              0.7517
# 4               1.5      0.9998      1.6882              1.6885
# 5               2.0      1.7775      5.3336              3.0007
# 6               2.5      2.7759     13.0121              4.6875
# 7               3.0      3.9978     26.9824              6.7493
# 8               3.5      5.4426      50.008              9.1883
# 9               4.0       7.107     85.2623             11.9969

# %%
dis_vals = ratio_data[1:, 0]
ratio_vals = ratio_data[1:, 3]

dis_vals_flt = []
ratio_vals_flt = []

for i, ratio in enumerate(ratio_vals):
    dispers = float(dis_vals[i])
    ratio = float(ratio)
    dis_vals_flt.append(dispers)
    ratio_vals_flt.append(ratio)

plt.plot(dis_vals_flt[1:], ratio_vals_flt[1:], linewidth=3)
plt.xlabel("Lobe Dispersion Factor\n(Scalar Change in Distance)", fontsize=18)
plt.xticks(fontsize=14)
plt.ylabel("Ratio Hexa:Quad", fontsize=18)
plt.yticks(fontsize=14)
plt.title("Hexadecapol:Quadrupol Ratio\nvs. Lobe Separation", fontsize=24)
plt.show()

# %%
#JET RESEMBLENSE
cen = 250

ratio_data = np.array([["Rotation (deg)", "Quad Value", "Hexa Value", "Hexa:Quad Ratio"]])

adder = 2.5
for angle in range(0,180,15):
    nx=500
    ny=500
    x=np.outer(np.linspace(-5,5,nx),np.ones(ny))
    y=np.outer(np.ones(nx),np.linspace(-5,5,ny))
    img=np.zeros((500, 500))
    

    x2=x+(adder*math.cos(-math.radians(angle)))
    y2=y+(adder*math.sin(-math.radians(angle)))
    x3=x-(adder*math.cos(-math.radians(angle)))
    y3=y-(adder*math.sin(-math.radians(angle)))
    r2=np.sqrt(x2**2 + y2**2)
    r3=np.sqrt(x3**2 + y3**2)
    re=np.sqrt(x**2 + y**2)


    img[re<0.5]=1

    img[r2<1.0]=1
    img[r3<1.0]=1

    plt.imshow(img)
    plt.show()






    # Quadruple moment:
    rsqr=x**2 + y**2
    q2=np.zeros([2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            q2[i,j]=1./2.*np.sum(img*(2*xy[i]*xy[j] - rsqr*dij))
    print("\n\nQuadrupol moment:\n\n",q2/np.sum(img))
    
    q2_norm = q2/np.sum(img)


    # Octupole moment:

    q3=np.zeros([2,2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            for k in [0,1]:
                if i==k:
                    dik=1
                else:
                    dik=0
                if j==k:
                    djk=1
                else:
                    djk=0
                q3[i,j,k]=1./2.*np.sum(img*(4*xy[i]*xy[j]*xy[k])) - np.sum(img*(rsqr*(xy[i]*djk + xy[j]*dik + xy[k]*dij)))
                
    q3_norm = q3/np.sum(img)
    print("\n\nOctupolpol moment:\n\n",q3_norm)
    
    
    

    # Hexadecapole moment:

    q4=np.zeros([2,2,2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            for k in [0,1]:
                if i==k:
                    dik=1
                else:
                    dik=0
                if j==k:
                    djk=1
                else:
                    djk=0
                for l in [0,1]:
                    if i==l:
                        dil=1
                    else:
                        dil=0
                    if j==l:
                        djl=1
                    else:
                        djl=0
                    if k==l:
                        dkl=1
                    else:
                        dkl=0
                    q4[i,j,k,l]=1./8.*np.sum(img*(24*xy[i]*xy[j]*xy[k]*xy[l] - 
                                           4*rsqr*(xy[k]*xy[l]*dij + xy[j]*xy[l]*dik + xy[j]*xy[k]*dil + xy[i]*xy[l]*djk + xy[i]*xy[k]*djl + xy[i]*xy[j]*dkl)) +
                                           img*(dij*dkl + dik*djl + dil*djk)*rsqr**2)

    print("\n\nHexadecapol moment:\n\n",q4/np.sum(img))
    q4_norm =q4/np.sum(img)
    
    quad_val = q2_norm[0,0]
    hexa_val = q4_norm[0,0,0,0]
    
    dis_data = np.array([angle, round(quad_val, 4), round(hexa_val, 4), round(hexa_val/quad_val, 4)])
    ratio_data = np.vstack([ratio_data, dis_data])

    print("\n\n")
    

    
data_table = pd.DataFrame(ratio_data)
        
print(data_table)
# Out:
# Quadrupol moment:
#
#  [[ 2.77592055e+00 -2.82660664e-18]
#  [-2.82660664e-18 -2.77592055e+00]]
#
#
# Octupolpol moment:
#
#  [[[ 4.95637440e-15 -1.04413022e-15]
#   [-1.03253388e-15  5.37585921e-15]]
#
#  [[-1.03253388e-15  5.37585921e-15]
#   [ 5.37585921e-15  3.65414276e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 1.30121245e+01  2.77555756e-17]
#    [-1.24786648e-17 -1.30121245e+01]]
#
#   [[-2.99992143e-18 -1.30121245e+01]
#    [-1.30121245e+01 -2.92681410e-17]]]
#
#
#  [[[-9.05018315e-18 -1.30121245e+01]
#    [-1.30121245e+01 -1.63861255e-18]]
#
#   [[-1.30121245e+01 -2.30162039e-17]
#    [-1.39408114e-17  1.30121245e+01]]]]
# Quadrupol moment:
#
#  [[ 2.403261   -1.38865474]
#  [-1.38865474 -2.403261  ]]
#
#
# Octupolpol moment:
#
#  [[[ 1.03304714e-15 -6.71480641e-16]
#   [-6.71480641e-16  6.71480641e-16]]
#
#  [[-6.71480641e-16  6.71480641e-16]
#   [ 6.71480641e-16  2.58584612e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[  6.48931616 -11.27099902]
#    [-11.27099902  -6.48931616]]
#
#   [[-11.27099902  -6.48931616]
#    [ -6.48931616  11.27099902]]]
#
#
#  [[[-11.27099902  -6.48931616]
#    [ -6.48931616  11.27099902]]
#
#   [[ -6.48931616  11.27099902]
#    [ 11.27099902   6.48931616]]]]
# Quadrupol moment:
#
#  [[ 1.38937914 -2.40208187]
#  [-2.40208187 -1.38937914]]
#
#
# Octupolpol moment:
#
#  [[[-1.65231239e-15 -1.03269524e-15]
#   [-1.44577334e-15  3.40789431e-15]]
#
#  [[-1.44577334e-15  3.40789431e-15]
#   [ 3.40789431e-15 -5.16347622e-16]]]
#
#
# Hexadecapol moment:
#
#  [[[[ -6.48017673 -11.2770029 ]
#    [-11.2770029    6.48017673]]
#
#   [[-11.2770029    6.48017673]
#    [  6.48017673  11.2770029 ]]]
#
#
#  [[[-11.2770029    6.48017673]
#    [  6.48017673  11.2770029 ]]
#
#   [[  6.48017673  11.2770029 ]
#    [ 11.2770029   -6.48017673]]]]
# Quadrupol moment:
#
#  [[ 0.         -2.77454942]
#  [-2.77454942  0.        ]]
#
#
# Octupolpol moment:
#
#  [[[-1.03210928e-15  2.47706228e-15]
#   [ 3.50917157e-15  2.52866775e-15]]
#
#  [[ 3.50917157e-15  2.52866775e-15]
#   [ 2.32224589e-15 -7.22476499e-16]]]
#
#
# Hexadecapol moment:
#
#  [[[[-1.29945260e+01 -1.03210928e-16]
#    [ 0.00000000e+00  1.29945260e+01]]
#
#   [[-4.12843714e-16  1.29945260e+01]
#    [ 1.29945260e+01  0.00000000e+00]]]
#
#
#  [[[-1.03210928e-16  1.29945260e+01]
#    [ 1.29945260e+01  0.00000000e+00]]
#
#   [[ 1.29945260e+01  0.00000000e+00]
#    [ 0.00000000e+00 -1.29945260e+01]]]]
# /tmp/ipykernel_23472/2735279011.py:122: RuntimeWarning: divide by zero encountered in double_scalars
#   dis_data = np.array([angle, round(quad_val, 4), round(hexa_val, 4), round(hexa_val/quad_val, 4)])
# Quadrupol moment:
#
#  [[-1.38937914 -2.40208187]
#  [-2.40208187  1.38937914]]
#
#
# Octupolpol moment:
#
#  [[[1.12951042e-15 5.71209557e-15]
#   [5.71209557e-15 2.57528377e-15]]
#
#  [[5.71209557e-15 2.57528377e-15]
#   [2.57528377e-15 7.29341016e-16]]]
#
#
# Hexadecapol moment:
#
#  [[[[ -6.48017673  11.2770029 ]
#    [ 11.2770029    6.48017673]]
#
#   [[ 11.2770029    6.48017673]
#    [  6.48017673 -11.2770029 ]]]
#
#
#  [[[ 11.2770029    6.48017673]
#    [  6.48017673 -11.2770029 ]]
#
#   [[  6.48017673 -11.2770029 ]
#    [-11.2770029   -6.48017673]]]]
# Quadrupol moment:
#
#  [[-2.403261   -1.38865474]
#  [-1.38865474  2.403261  ]]
#
#
# Octupolpol moment:
#
#  [[[ 1.98215920e-15  3.78353515e-15]
#   [ 3.69314352e-15 -7.74785355e-16]]
#
#  [[ 3.69314352e-15 -7.74785355e-16]
#   [-5.68175927e-16  7.23132998e-16]]]
#
#
# Hexadecapol moment:
#
#  [[[[  6.48931616  11.27099902]
#    [ 11.27099902  -6.48931616]]
#
#   [[ 11.27099902  -6.48931616]
#    [ -6.48931616 -11.27099902]]]
#
#
#  [[[ 11.27099902  -6.48931616]
#    [ -6.48931616 -11.27099902]]
#
#   [[ -6.48931616 -11.27099902]
#    [-11.27099902   6.48931616]]]]
# Quadrupol moment:
#
#  [[-2.77592055e+00 -4.03350781e-19]
#  [-4.03350781e-19  2.77592055e+00]]
#
#
# Octupolpol moment:
#
#  [[[ 3.76245608e-15  3.63338383e-15]
#   [ 3.64225755e-15 -1.27781527e-15]]
#
#  [[ 3.64225755e-15 -1.27781527e-15]
#   [-1.27781527e-15  4.38200288e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 1.30121245e+01  3.06546594e-17]
#    [ 2.42010469e-17 -1.30121245e+01]]
#
#   [[ 3.71082718e-17 -1.30121245e+01]
#    [-1.30121245e+01 -1.61340312e-18]]]
#
#
#  [[[ 3.06546594e-17 -1.30121245e+01]
#    [-1.30121245e+01  1.61340312e-18]]
#
#   [[-1.30121245e+01 -1.45206281e-17]
#    [-1.77474344e-17  1.30121245e+01]]]]
# Quadrupol moment:
#
#  [[-2.403261    1.38865474]
#  [ 1.38865474  2.403261  ]]
#
#
# Octupolpol moment:
#
#  [[[ 5.55262838e-15  1.38170055e-15]
#   [ 1.38170055e-15 -8.78090069e-16]]
#
#  [[ 1.38170055e-15 -8.78090069e-16]
#   [-8.78090069e-16  7.54124412e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[  6.48931616 -11.27099902]
#    [-11.27099902  -6.48931616]]
#
#   [[-11.27099902  -6.48931616]
#    [ -6.48931616  11.27099902]]]
#
#
#  [[[-11.27099902  -6.48931616]
#    [ -6.48931616  11.27099902]]
#
#   [[ -6.48931616  11.27099902]
#    [ 11.27099902   6.48931616]]]]
# Quadrupol moment:
#
#  [[-1.38937914  2.40208187]
#  [ 2.40208187  1.38937914]]
#
#
# Octupolpol moment:
#
#  [[[ 5.47328480e-15  1.98148400e-15]
#   [ 1.98148400e-15 -7.48704052e-16]]
#
#  [[ 1.98148400e-15 -7.48704052e-16]
#   [-9.61697446e-16  1.00235982e-14]]]
#
#
# Hexadecapol moment:
#
#  [[[[ -6.48017673 -11.2770029 ]
#    [-11.2770029    6.48017673]]
#
#   [[-11.2770029    6.48017673]
#    [  6.48017673  11.2770029 ]]]
#
#
#  [[[-11.2770029    6.48017673]
#    [  6.48017673  11.2770029 ]]
#
#   [[  6.48017673  11.2770029 ]
#    [ 11.2770029   -6.48017673]]]]
# Quadrupol moment:
#
#  [[-2.58027321e-17  2.77454942e+00]
#  [ 2.77454942e+00  0.00000000e+00]]
#
#
# Octupolpol moment:
#
#  [[[ 1.85779671e-15  2.37385136e-15]
#   [ 2.27064043e-15 -7.22476499e-16]]
#
#  [[ 2.27064043e-15 -7.22476499e-16]
#   [-7.22476499e-16  9.08256171e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[-1.29945260e+01  0.00000000e+00]
#    [-2.06421857e-16  1.29945260e+01]]
#
#   [[ 2.06421857e-16  1.29945260e+01]
#    [ 1.29945260e+01  2.06421857e-16]]]
#
#
#  [[[ 0.00000000e+00  1.29945260e+01]
#    [ 1.29945260e+01  0.00000000e+00]]
#
#   [[ 1.29945260e+01  2.06421857e-16]
#    [ 2.06421857e-16 -1.29945260e+01]]]]
# Quadrupol moment:
#
#  [[ 1.38937914  2.40208187]
#  [ 2.40208187 -1.38937914]]
#
#
# Octupolpol moment:
#
#  [[[2.89154668e-15 0.00000000e+00]
#   [0.00000000e+00 1.70394715e-15]]
#
#  [[0.00000000e+00 1.70394715e-15]
#   [1.96212096e-15 6.09290194e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[ -6.48017673  11.2770029 ]
#    [ 11.2770029    6.48017673]]
#
#   [[ 11.2770029    6.48017673]
#    [  6.48017673 -11.2770029 ]]]
#
#
#  [[[ 11.2770029    6.48017673]
#    [  6.48017673 -11.2770029 ]]
#
#   [[  6.48017673 -11.2770029 ]
#    [-11.2770029   -6.48017673]]]]
# Quadrupol moment:
#
#  [[ 2.403261    1.38865474]
#  [ 1.38865474 -2.403261  ]]
#
#
# Octupolpol moment:
#
#  [[[ 1.05370808e-14 -2.42766078e-15]
#   [-2.32435606e-15  3.80936133e-15]]
#
#  [[-2.32435606e-15  3.80936133e-15]
#   [ 3.80936133e-15  4.60674459e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[  6.48931616  11.27099902]
#    [ 11.27099902  -6.48931616]]
#
#   [[ 11.27099902  -6.48931616]
#    [ -6.48931616 -11.27099902]]]
#
#
#  [[[ 11.27099902  -6.48931616]
#    [ -6.48931616 -11.27099902]]
#
#   [[ -6.48931616 -11.27099902]
#    [-11.27099902   6.48931616]]]]
#
#
#
#                  0           1           2                      3
# 0   Rotation (deg)  Quad Value  Hexa Value        Hexa:Quad Ratio
# 1              0.0      2.7759     13.0121                 4.6875
# 2             15.0      2.4033      6.4893                 2.7002
# 3             30.0      1.3894     -6.4802                -4.6641
# 4             45.0         0.0    -12.9945                   -inf
# 5             60.0     -1.3894     -6.4802                 4.6641
# 6             75.0     -2.4033      6.4893                -2.7002
# 7             90.0     -2.7759     13.0121                -4.6875
# 8            105.0     -2.4033      6.4893                -2.7002
# 9            120.0     -1.3894     -6.4802                 4.6641
# 10           135.0        -0.0    -12.9945  5.036104667554646e+17
# 11           150.0      1.3894     -6.4802                -4.6641
# 12           165.0      2.4033      6.4893                 2.7002

# %%
#JET RESEMBLENSE
cen = 250

ratio_data = np.array([["Rotation (deg)", "Quad Value", "Hexa Value", "Hexa:Quad Ratio"]])

adder = 2.5
for angle in range(0,180,2):
    nx=500
    ny=500
    x=np.outer(np.linspace(-5,5,nx),np.ones(ny))
    y=np.outer(np.ones(nx),np.linspace(-5,5,ny))
    img=np.zeros((500, 500))
    

    x2=x+(adder*math.cos(-math.radians(angle)))
    y2=y+(adder*math.sin(-math.radians(angle)))
    x3=x-(adder*math.cos(-math.radians(angle)))
    y3=y-(adder*math.sin(-math.radians(angle)))
    r2=np.sqrt(x2**2 + y2**2)
    r3=np.sqrt(x3**2 + y3**2)
    re=np.sqrt(x**2 + y**2)


    img[re<0.5]=1

    img[r2<1.0]=1
    img[r3<1.0]=1

    if angle%30 == 0:
        plt.imshow(img)
        plt.show()



    # Quadruple moment:
    rsqr=x**2 + y**2
    q2=np.zeros([2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            q2[i,j]=1./2.*np.sum(img*(2*xy[i]*xy[j] - rsqr*dij))
    #print("\n\nQuadrupol moment:\n\n",q2/np.sum(img))
    
    q2_norm = q2/np.sum(img)


    # Octupole moment:

    q3=np.zeros([2,2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            for k in [0,1]:
                if i==k:
                    dik=1
                else:
                    dik=0
                if j==k:
                    djk=1
                else:
                    djk=0
                q3[i,j,k]=1./2.*np.sum(img*(4*xy[i]*xy[j]*xy[k])) - np.sum(img*(rsqr*(xy[i]*djk + xy[j]*dik + xy[k]*dij)))
                
    q3_norm = q3/np.sum(img)
    #print("\n\nOctupolpol moment:\n\n",q3_norm)
    
    
    

    # Hexadecapole moment:

    q4=np.zeros([2,2,2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            for k in [0,1]:
                if i==k:
                    dik=1
                else:
                    dik=0
                if j==k:
                    djk=1
                else:
                    djk=0
                for l in [0,1]:
                    if i==l:
                        dil=1
                    else:
                        dil=0
                    if j==l:
                        djl=1
                    else:
                        djl=0
                    if k==l:
                        dkl=1
                    else:
                        dkl=0
                    q4[i,j,k,l]=1./8.*np.sum(img*(24*xy[i]*xy[j]*xy[k]*xy[l] - 
                                           4*rsqr*(xy[k]*xy[l]*dij + xy[j]*xy[l]*dik + xy[j]*xy[k]*dil + xy[i]*xy[l]*djk + xy[i]*xy[k]*djl + xy[i]*xy[j]*dkl)) +
                                           img*(dij*dkl + dik*djl + dil*djk)*rsqr**2)

    #print("\n\nHexadecapol moment:\n\n",q4/np.sum(img))
    q4_norm =q4/np.sum(img)
    
    quad_val = q2_norm[0,0]
    hexa_val = q4_norm[0,0,0,0]
    hexaquad = round(hexa_val/quad_val, 4)
    
    if abs(hexaquad) > 50:
        hexaquad = np.nan
    
    dis_data = np.array([angle, round(quad_val, 4), round(hexa_val, 4), hexaquad])
    ratio_data = np.vstack([ratio_data, dis_data])

    #print("\n\n")
    

    
data_table = pd.DataFrame(ratio_data)
        
print(data_table)
# Out:
#                  0           1           2                3
# 0   Rotation (deg)  Quad Value  Hexa Value  Hexa:Quad Ratio
# 1              0.0      2.7759     13.0121           4.6875
# 2              2.0      2.7689     12.8881           4.6546
# 3              4.0      2.7495     12.5085           4.5494
# 4              6.0      2.7164      11.896           4.3793
# ..             ...         ...         ...              ...
# 86           170.0      2.6089      9.9707           3.8218
# 87           172.0      2.6672     11.0173           4.1307
# 88           174.0      2.7164      11.896           4.3793
# 89           176.0      2.7495     12.5085           4.5494
# 90           178.0      2.7689     12.8881           4.6546
#
# [91 rows x 4 columns]

# %%
plt.rcParams["figure.figsize"] = (6,5)
rot_vals = ratio_data[1:, 0]
ratio_vals = ratio_data[1:, 3]

rot_vals_flt = []
ratio_vals_flt = []

for i, ratio in enumerate(ratio_vals):
    dispers = float(rot_vals[i])
    ratio = float(ratio)
    rot_vals_flt.append(dispers)
    ratio_vals_flt.append(ratio)

abs_ratio_vals_flt = [abs(number) for number in ratio_vals_flt]

plt.plot(rot_vals_flt, ratio_vals_flt, linewidth=3)
#plt.yscale("log")
plt.ylim([-28, 28])
plt.xlabel("Lobe Rotation (deg)", fontsize=18)
plt.xticks(fontsize=14)
plt.ylabel("Ratio Hexa:Quad", fontsize=18)
plt.yticks(fontsize=14)
plt.title("Hexadecapol:Quadrupol Ratio\nvs. Lobe Rotation", fontsize=24)
plt.show()


plt.plot(rot_vals_flt, abs_ratio_vals_flt, linewidth=3)
#plt.yscale("log")
plt.xlabel("Lobe Rotation (deg)", fontsize=18)
plt.xticks(fontsize=14)
plt.ylabel("Abs. Ratio Hexa:Quad", fontsize=18)
plt.yticks(fontsize=14)
plt.title("Hexadecapol:Quadrupol Ratio\nvs. Lobe Rotation", fontsize=24)
plt.show()


# plt.plot(dis_vals_flt[1:], ratio_vals_flt[1:], linewidth=3)
# plt.xlabel("Lobe Dispersion Factor\n(Scalar Change in Distance)", fontsize=18)
# plt.xticks(fontsize=14)
# plt.ylabel("Ratio Hexa:Quad", fontsize=18)
# plt.yticks(fontsize=14)
# plt.title("Hexadecapol:Quadrupol Ratio\nvs. Lobe Separation", fontsize=24)
# plt.show()

# plt.plot(dis_vals_flt[1:], ratio_vals_flt[1:], linewidth=3)
# plt.yscale("log")
# plt.xlabel("Lobe Dispersion Factor\n(Scalar Change in Distance)", fontsize=18)
# plt.xticks(fontsize=14)
# plt.ylabel("Ratio Hexa:Quad", fontsize=18)
# plt.yticks(fontsize=14)
# plt.title("Hexadecapol:Quadrupol Ratio\nvs. Lobe Separation", fontsize=24)
# plt.show()

# %%
#JET RESEMBLENSE
cen = 250

ratio_data = np.array([["Rotation (deg)", "Quad Value", "Hexa Value", "Hexa:Quad Ratio"]])

adder = 2.5
for angle in [0, 15, 30, 45, 60, 75, 90]:
    nx=500
    ny=500
    x=np.outer(np.linspace(-5,5,nx),np.ones(ny))
    y=np.outer(np.ones(nx),np.linspace(-5,5,ny))
    img=np.zeros((500, 500))
    

    x2=x+(adder*math.cos(-math.radians(angle)))
    y2=y+(adder*math.sin(-math.radians(angle)))
    x3=x-(adder*math.cos(math.radians(angle)))
    y3=y-(adder*math.sin(math.radians(angle)))
    r2=np.sqrt(x2**2 + y2**2)
    r3=np.sqrt(x3**2 + y3**2)
    re=np.sqrt(x**2 + y**2)


    img[re<0.5]=1

    img[r2<1.0]=1
    img[r3<1.0]=1


    plt.imshow(img)
    plt.show()






    # Quadruple moment:
    rsqr=x**2 + y**2
    q2=np.zeros([2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            q2[i,j]=1./2.*np.sum(img*(2*xy[i]*xy[j] - rsqr*dij))
    print("\n\nQuadrupol moment:\n\n",q2/np.sum(img))
    
    q2_norm = q2/np.sum(img)


    # Octupole moment:

    q3=np.zeros([2,2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            for k in [0,1]:
                if i==k:
                    dik=1
                else:
                    dik=0
                if j==k:
                    djk=1
                else:
                    djk=0
                q3[i,j,k]=1./2.*np.sum(img*(4*xy[i]*xy[j]*xy[k])) - np.sum(img*(rsqr*(xy[i]*djk + xy[j]*dik + xy[k]*dij)))
                
    q3_norm = q3/np.sum(img)
    print("\n\nOctupolpol moment:\n\n",q3_norm)
    
    
    

    # Hexadecapole moment:

    q4=np.zeros([2,2,2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            for k in [0,1]:
                if i==k:
                    dik=1
                else:
                    dik=0
                if j==k:
                    djk=1
                else:
                    djk=0
                for l in [0,1]:
                    if i==l:
                        dil=1
                    else:
                        dil=0
                    if j==l:
                        djl=1
                    else:
                        djl=0
                    if k==l:
                        dkl=1
                    else:
                        dkl=0
                    q4[i,j,k,l]=1./8.*np.sum(img*(24*xy[i]*xy[j]*xy[k]*xy[l] - 
                                           4*rsqr*(xy[k]*xy[l]*dij + xy[j]*xy[l]*dik + xy[j]*xy[k]*dil + xy[i]*xy[l]*djk + xy[i]*xy[k]*djl + xy[i]*xy[j]*dkl)) +
                                           img*(dij*dkl + dik*djl + dil*djk)*rsqr**2)

    print("\n\nHexadecapol moment:\n\n",q4/np.sum(img))
    q4_norm =q4/np.sum(img)
    
    quad_val = q2_norm[0,0]
    hexa_val = q4_norm[0,0,0,0]
    
    dis_data = np.array([angle, round(quad_val, 4), round(hexa_val, 4), round(hexa_val/quad_val, 4)])
    ratio_data = np.vstack([ratio_data, dis_data])

    print("\n\n")
    

    
data_table = pd.DataFrame(ratio_data)
        
print(data_table)
# Out:
# Quadrupol moment:
#
#  [[ 2.77592055e+00 -2.82660664e-18]
#  [-2.82660664e-18 -2.77592055e+00]]
#
#
# Octupolpol moment:
#
#  [[[ 4.95637440e-15 -1.04413022e-15]
#   [-1.03253388e-15  5.37585921e-15]]
#
#  [[-1.03253388e-15  5.37585921e-15]
#   [ 5.37585921e-15  3.65414276e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 1.30121245e+01  2.77555756e-17]
#    [-1.24786648e-17 -1.30121245e+01]]
#
#   [[-2.99992143e-18 -1.30121245e+01]
#    [-1.30121245e+01 -2.92681410e-17]]]
#
#
#  [[[-9.05018315e-18 -1.30121245e+01]
#    [-1.30121245e+01 -1.63861255e-18]]
#
#   [[-1.30121245e+01 -2.30162039e-17]
#    [-1.39408114e-17  1.30121245e+01]]]]
# Quadrupol moment:
#
#  [[ 2.40326100e+00 -5.81089016e-17]
#  [-5.81089016e-17 -2.40326100e+00]]
#
#
# Octupolpol moment:
#
#  [[[ 2.27270371e-15  2.82427502e+00]
#   [ 2.82427502e+00  1.33004819e-15]]
#
#  [[ 2.82427502e+00  1.33004819e-15]
#   [ 1.33004819e-15 -1.11638463e+01]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 6.48931616e+00 -3.30575085e-15]
#    [-3.30575085e-15 -6.48931616e+00]]
#
#   [[-3.30575085e-15 -6.48931616e+00]
#    [-6.48931616e+00  2.89253199e-15]]]
#
#
#  [[[-3.30575085e-15 -6.48931616e+00]
#    [-6.48931616e+00  2.89253199e-15]]
#
#   [[-6.48931616e+00  2.89253199e-15]
#    [ 2.89253199e-15  6.48931616e+00]]]]
# Quadrupol moment:
#
#  [[ 1.38937914e+00 -3.09808573e-16]
#  [-3.09808573e-16 -1.38937914e+00]]
#
#
# Octupolpol moment:
#
#  [[[-4.13078098e-16  2.91684612e+00]
#   [ 2.91684612e+00  3.35625954e-15]]
#
#  [[ 2.91684612e+00  3.35625954e-15]
#   [ 3.61443336e-15 -1.89970594e+01]]]
#
#
# Hexadecapol moment:
#
#  [[[[-6.48017673e+00 -4.33732003e-15]
#    [-4.13078098e-15  6.48017673e+00]]
#
#   [[-4.13078098e-15  6.48017673e+00]
#    [ 6.48017673e+00  5.78309337e-15]]]
#
#
#  [[[-5.37001527e-15  6.48017673e+00]
#    [ 6.48017673e+00  5.37001527e-15]]
#
#   [[ 6.48017673e+00  4.95693717e-15]
#    [ 5.37001527e-15 -6.48017673e+00]]]]
# Quadrupol moment:
#
#  [[ 3.35435518e-16 -2.83830053e-16]
#  [-2.83830053e-16 -3.61238250e-16]]
#
#
# Octupolpol moment:
#
#  [[[ 1.03210928e-15 -7.86170647e-01]
#   [-7.86170647e-01  1.03210928e-16]]
#
#  [[-7.86170647e-01  1.03210928e-16]
#   [ 1.03210928e-16 -2.19702356e+01]]]
#
#
# Hexadecapol moment:
#
#  [[[[-1.29945260e+01 -2.88990600e-15]
#    [-3.09632785e-15  1.29945260e+01]]
#
#   [[-3.30274971e-15  1.29945260e+01]
#    [ 1.29945260e+01  3.09632785e-15]]]
#
#
#  [[[-2.88990600e-15  1.29945260e+01]
#    [ 1.29945260e+01  2.88990600e-15]]
#
#   [[ 1.29945260e+01  3.09632785e-15]
#    [ 3.09632785e-15 -1.29945260e+01]]]]
# Quadrupol moment:
#
#  [[-1.38937914e+00 -1.96857531e-16]
#  [-1.96857531e-16  1.38937914e+00]]
#
#
# Octupolpol moment:
#
#  [[[ 3.40789431e-15 -6.97934339e+00]
#   [-6.97934339e+00  9.03608339e-16]]
#
#  [[-6.97934339e+00  9.03608339e-16]
#   [ 6.90614945e-16 -2.09004833e+01]]]
#
#
# Hexadecapol moment:
#
#  [[[[-6.48017673e+00 -2.82377606e-16]
#    [-2.83184399e-16  6.48017673e+00]]
#
#   [[-2.83991192e-16  6.48017673e+00]
#    [ 6.48017673e+00  3.96942235e-16]]]
#
#
#  [[[-3.35625954e-16  6.48017673e+00]
#    [ 6.48017673e+00  1.90403186e-16]]
#
#   [[ 6.48017673e+00  1.38768423e-16]
#    [-2.23481705e-16 -6.48017673e+00]]]]
# Quadrupol moment:
#
#  [[-2.33732476e+00 -4.40366847e-16]
#  [-4.40366847e-16  2.33732476e+00]]
#
#
# Octupolpol moment:
#
#  [[[ 4.24484764e-15 -1.24159358e+01]
#   [-1.24159358e+01 -5.77530291e-17]]
#
#  [[-1.24159358e+01 -5.77530291e-17]
#   [-5.77530291e-17 -1.88051531e+01]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 5.60673183e+00  3.34967569e-15]
#    [ 3.34967569e-15 -5.60673183e+00]]
#
#   [[ 2.45450374e-15 -5.60673183e+00]
#    [-5.60673183e+00 -2.45450374e-15]]]
#
#
#  [[[ 2.45450374e-15 -5.60673183e+00]
#    [-5.60673183e+00 -2.45450374e-15]]
#
#   [[-5.60673183e+00 -2.42562722e-15]
#    [-2.45450374e-15  5.60673183e+00]]]]
# Quadrupol moment:
#
#  [[-2.49696775e+00 -4.00551052e-16]
#  [-4.00551052e-16  2.49696775e+00]]
#
#
# Octupolpol moment:
#
#  [[[ 3.17538298e-15 -1.34838249e+01]
#   [-1.34838249e+01 -1.07974631e-15]]
#
#  [[-1.34838249e+01 -1.07974631e-15]
#   [-1.07974631e-15 -1.54821961e+01]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 1.17045319e+01  3.25084912e-15]
#    [ 3.25084912e-15 -1.17045319e+01]]
#
#   [[ 3.25084912e-15 -1.17045319e+01]
#    [-1.17045319e+01 -3.25084912e-15]]]
#
#
#  [[[ 3.25084912e-15 -1.17045319e+01]
#    [-1.17045319e+01 -3.25084912e-15]]
#
#   [[-1.17045319e+01 -3.29728982e-15]
#    [-3.25084912e-15  1.17045319e+01]]]]
#
#
#
#                 0           1           2                       3
# 0  Rotation (deg)  Quad Value  Hexa Value         Hexa:Quad Ratio
# 1             0.0      2.7759     13.0121                  4.6875
# 2            15.0      2.4033      6.4893                  2.7002
# 3            30.0      1.3894     -6.4802                 -4.6641
# 4            45.0         0.0    -12.9945  -3.873926667349727e+16
# 5            60.0     -1.3894     -6.4802                  4.6641
# 6            75.0     -2.3373      5.6067                 -2.3988
# 7            90.0      -2.497     11.7045                 -4.6875

# %%
#JET RESEMBLENSE
cen = 250

ratio_data = np.array([["Rotation (deg)", "Quad Value", "Hexa Value", "Hexa:Quad Ratio"]])

adder = 2.5
for angle in range(0,90):
    nx=500
    ny=500
    x=np.outer(np.linspace(-5,5,nx),np.ones(ny))
    y=np.outer(np.ones(nx),np.linspace(-5,5,ny))
    img=np.zeros((500, 500))
    

    x2=x+(adder*math.cos(-math.radians(angle)))
    y2=y+(adder*math.sin(-math.radians(angle)))
    x3=x-(adder*math.cos(math.radians(angle)))
    y3=y-(adder*math.sin(math.radians(angle)))
    r2=np.sqrt(x2**2 + y2**2)
    r3=np.sqrt(x3**2 + y3**2)
    re=np.sqrt(x**2 + y**2)


    img[re<0.5]=1

    img[r2<1.0]=1
    img[r3<1.0]=1

    if angle%15 == 0:
        plt.imshow(img)
        plt.show()



    # Quadruple moment:
    rsqr=x**2 + y**2
    q2=np.zeros([2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            q2[i,j]=1./2.*np.sum(img*(2*xy[i]*xy[j] - rsqr*dij))
    #print("\n\nQuadrupol moment:\n\n",q2/np.sum(img))
    
    q2_norm = q2/np.sum(img)


    # Octupole moment:

    q3=np.zeros([2,2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            for k in [0,1]:
                if i==k:
                    dik=1
                else:
                    dik=0
                if j==k:
                    djk=1
                else:
                    djk=0
                q3[i,j,k]=1./2.*np.sum(img*(4*xy[i]*xy[j]*xy[k])) - np.sum(img*(rsqr*(xy[i]*djk + xy[j]*dik + xy[k]*dij)))
                
    q3_norm = q3/np.sum(img)
    #print("\n\nOctupolpol moment:\n\n",q3_norm)
    
    
    

    # Hexadecapole moment:

    q4=np.zeros([2,2,2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            for k in [0,1]:
                if i==k:
                    dik=1
                else:
                    dik=0
                if j==k:
                    djk=1
                else:
                    djk=0
                for l in [0,1]:
                    if i==l:
                        dil=1
                    else:
                        dil=0
                    if j==l:
                        djl=1
                    else:
                        djl=0
                    if k==l:
                        dkl=1
                    else:
                        dkl=0
                    q4[i,j,k,l]=1./8.*np.sum(img*(24*xy[i]*xy[j]*xy[k]*xy[l] - 
                                           4*rsqr*(xy[k]*xy[l]*dij + xy[j]*xy[l]*dik + xy[j]*xy[k]*dil + xy[i]*xy[l]*djk + xy[i]*xy[k]*djl + xy[i]*xy[j]*dkl)) +
                                           img*(dij*dkl + dik*djl + dil*djk)*rsqr**2)

    #print("\n\nHexadecapol moment:\n\n",q4/np.sum(img))
    q4_norm =q4/np.sum(img)
    
    quad_val = q2_norm[0,0]
    hexa_val = q4_norm[0,0,0,0]
    hexaquad = round(hexa_val/quad_val, 4)
    
    if abs(hexaquad) > 120:
        hexaquad = np.nan
    
    dis_data = np.array([angle, round(quad_val, 4), round(hexa_val, 4), hexaquad])
    ratio_data = np.vstack([ratio_data, dis_data])

    #print("\n\n")
    

    
data_table = pd.DataFrame(ratio_data)
        
print(data_table)
# Out:
#                  0           1           2                3
# 0   Rotation (deg)  Quad Value  Hexa Value  Hexa:Quad Ratio
# 1              0.0      2.7759     13.0121           4.6875
# 2              1.0      2.7754     12.9905           4.6806
# 3              2.0      2.7689     12.8881           4.6546
# 4              3.0      2.7579     12.7047           4.6066
# ..             ...         ...         ...              ...
# 86            85.0     -2.5412     10.6991          -4.2103
# 87            86.0     -2.5415      10.989          -4.3238
# 88            87.0      -2.534     11.2193          -4.4275
# 89            88.0     -2.5291     11.4577          -4.5303
# 90            89.0     -2.5173     11.6245          -4.6178
#
# [91 rows x 4 columns]

# %%
plt.rcParams["figure.figsize"] = (6,5)
rot_vals = ratio_data[1:, 0]
ratio_vals = ratio_data[1:, 3]

rot_vals_flt = []
ratio_vals_flt = []

for i, ratio in enumerate(ratio_vals):
    dispers = float(rot_vals[i])
    ratio = float(ratio)
    rot_vals_flt.append(dispers)
    ratio_vals_flt.append(ratio)

abs_ratio_vals_flt = [abs(number) for number in ratio_vals_flt]

plt.plot(rot_vals_flt, ratio_vals_flt, linewidth=3)
#plt.yscale("log")
plt.ylim([-50, 50])
plt.xlabel("Lobe Rotation (deg)", fontsize=18)
plt.xticks(fontsize=14)
plt.ylabel("Ratio Hexa:Quad", fontsize=18)
plt.yticks(fontsize=14)
plt.title("Hexadecapol:Quadrupol Ratio\nvs. Lobe Rotation", fontsize=24)
plt.show()


plt.plot(rot_vals_flt, abs_ratio_vals_flt, linewidth=3)
#plt.yscale("log")
plt.xlabel("Lobe Rotation (deg)", fontsize=18)
plt.xticks(fontsize=14)
plt.ylabel("Abs. Ratio Hexa:Quad", fontsize=18)
plt.yticks(fontsize=14)
plt.title("Hexadecapol:Quadrupol Ratio\nvs. Lobe Rotation", fontsize=24)
plt.show()


# plt.plot(dis_vals_flt[1:], ratio_vals_flt[1:], linewidth=3)
# plt.xlabel("Lobe Dispersion Factor\n(Scalar Change in Distance)", fontsize=18)
# plt.xticks(fontsize=14)
# plt.ylabel("Ratio Hexa:Quad", fontsize=18)
# plt.yticks(fontsize=14)
# plt.title("Hexadecapol:Quadrupol Ratio\nvs. Lobe Separation", fontsize=24)
# plt.show()

# plt.plot(dis_vals_flt[1:], ratio_vals_flt[1:], linewidth=3)
# plt.yscale("log")
# plt.xlabel("Lobe Dispersion Factor\n(Scalar Change in Distance)", fontsize=18)
# plt.xticks(fontsize=14)
# plt.ylabel("Ratio Hexa:Quad", fontsize=18)
# plt.yticks(fontsize=14)
# plt.title("Hexadecapol:Quadrupol Ratio\nvs. Lobe Separation", fontsize=24)
# plt.show()
