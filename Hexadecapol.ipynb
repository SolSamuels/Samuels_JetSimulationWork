# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#SQUARES
cen = 250


for offset in range(3):
    adder = 50
    for size in range(3):

        nx=500
        ny=500
        x=np.outer(np.linspace(-5,5,nx),np.ones(ny))
        y=np.outer(np.ones(nx),np.linspace(-5,5,ny))
        img=np.zeros((500, 500))

        sq_b1 = cen - adder
        sq_b2 = cen + adder

        for col in range(nx):
            for row in range(ny):
                if (sq_b1<col<sq_b2) and (sq_b1<row<sq_b2):
                    img[col, row]=1

        plt.imshow(img)
        plt.show()





        # Quadruple moment:
        rsqr=x**2 + y**2
        q2=np.zeros([2,2])
        xy=[x,y]
        for i in [0,1]:
            for j in [0,1]:
                if i==j:
                    dij=1
                else:
                    dij=0
                q2[i,j]=1./2.*np.sum(img*(2*xy[i]*xy[j] - rsqr*dij))
        print("\n\nQuadrupol moment:\n\n",q2/np.sum(img))


        # Octupole moment:

        q3=np.zeros([2,2,2])
        xy=[x,y]
        for i in [0,1]:
            for j in [0,1]:
                if i==j:
                    dij=1
                else:
                    dij=0
                for k in [0,1]:
                    if i==k:
                        dik=1
                    else:
                        dik=0
                    if j==k:
                        djk=1
                    else:
                        djk=0
                    q3[i,j,k]=1./2.*np.sum(img*(4*xy[i]*xy[j]*xy[k])) - np.sum(img*(rsqr*(xy[i]*djk + xy[j]*dik + xy[k]*dij)))
        print("\n\nOctupolpol moment:\n\n",q3/np.sum(img))

        # Hexadecapole moment:

        q4=np.zeros([2,2,2,2])
        xy=[x,y]
        for i in [0,1]:
            for j in [0,1]:
                if i==j:
                    dij=1
                else:
                    dij=0
                for k in [0,1]:
                    if i==k:
                        dik=1
                    else:
                        dik=0
                    if j==k:
                        djk=1
                    else:
                        djk=0
                    for l in [0,1]:
                        if i==l:
                            dil=1
                        else:
                            dil=0
                        if j==l:
                            djl=1
                        else:
                            djl=0
                        if k==l:
                            dkl=1
                        else:
                            dkl=0
                        q4[i,j,k,l]=1./8.*np.sum(img*(24*xy[i]*xy[j]*xy[k]*xy[l] - 
                                               4*rsqr*(xy[k]*xy[l]*dij + xy[j]*xy[l]*dik + xy[j]*xy[k]*dil + xy[i]*xy[l]*djk + xy[i]*xy[k]*djl + xy[i]*xy[j]*dkl)) +
                                               img*(dij*dkl + dik*djl + dil*djk)*rsqr**2)

        print("\n\nHexadecapol moment:\n\n",q4/np.sum(img))

        adder += 25

        print("\n\n")
    
    cen += 50
# Out:
# Quadrupol moment:
#
#  [[-5.79975705e-18  1.00401203e-04]
#  [ 1.00401203e-04 -5.79975705e-18]]
#
#
# Octupolpol moment:
#
#  [[[-0.0197221  -0.00657269]
#   [-0.00657269 -0.00657269]]
#
#  [[-0.00657269 -0.00657269]
#   [-0.00657269 -0.0197221 ]]]
#
#
# Hexadecapol moment:
#
#  [[[[-9.68319497e-02 -6.57003728e-19]
#    [-1.91437293e-18  9.68319497e-02]]
#
#   [[-2.49208311e-19  9.68319497e-02]
#    [ 9.68319497e-02 -5.43727224e-19]]]
#
#
#  [[[-2.49208311e-19  9.68319497e-02]
#    [ 9.68319497e-02 -5.43727224e-19]]
#
#   [[ 9.68319497e-02 -9.06212039e-19]
#    [-1.11010975e-18 -9.68319497e-02]]]]
# Quadrupol moment:
#
#  [[0.00000000e+00 1.00401203e-04]
#  [1.00401203e-04 1.02415961e-17]]
#
#
# Octupolpol moment:
#
#  [[[-0.04467149 -0.01488916]
#   [-0.01488916 -0.01488916]]
#
#  [[-0.01488916 -0.01488916]
#   [-0.01488916 -0.04467149]]]
#
#
# Hexadecapol moment:
#
#  [[[[-4.96847285e-01 -3.20049879e-18]
#    [-7.68119709e-18  4.96847285e-01]]
#
#   [[-3.84059854e-18  4.96847285e-01]
#    [ 4.96847285e-01 -3.20049879e-18]]]
#
#
#  [[[-1.60024939e-18  4.96847285e-01]
#    [ 4.96847285e-01 -3.84059854e-18]]
#
#   [[ 4.96847285e-01 -6.08094770e-18]
#    [ 2.56039903e-18 -4.96847285e-01]]]]
# Quadrupol moment:
#
#  [[1.14832290e-17 1.00401203e-04]
#  [1.00401203e-04 0.00000000e+00]]
#
#
# Octupolpol moment:
#
#  [[[-0.07968113 -0.02655904]
#   [-0.02655904 -0.02655904]]
#
#  [[-0.02655904 -0.02655904]
#   [-0.02655904 -0.07968113]]]
#
#
# Hexadecapol moment:
#
#  [[[[-1.58084811e+00  1.04066763e-17]
#    [ 5.74161449e-18  1.58084811e+00]]
#
#   [[ 6.10046540e-18  1.58084811e+00]
#    [ 1.58084811e+00 -6.36960358e-18]]]
#
#
#  [[[ 4.66506177e-18  1.58084811e+00]
#    [ 1.58084811e+00  8.97127264e-20]]
#
#   [[ 1.58084811e+00 -6.90787993e-18]
#    [-4.66506177e-18 -1.58084811e+00]]]]
# Quadrupol moment:
#
#  [[-1.15995141e-17  1.02419267e+00]
#  [ 1.02419267e+00  0.00000000e+00]]
#
#
# Octupolpol moment:
#
#  [[[-6.13755573 -0.66384176]
#   [-0.66384176 -0.66384176]]
#
#  [[-0.66384176 -0.66384176]
#   [-0.66384176 -6.13755573]]]
#
#
# Hexadecapol moment:
#
#  [[[[-1.67028788e+00  0.00000000e+00]
#    [-9.27961128e-17  1.67028788e+00]]
#
#   [[ 9.27961128e-17  1.67028788e+00]
#    [ 1.67028788e+00 -4.63980564e-17]]]
#
#
#  [[[ 9.27961128e-17  1.67028788e+00]
#    [ 1.67028788e+00 -4.63980564e-17]]
#
#   [[ 1.67028788e+00 -4.63980564e-17]
#    [-4.63980564e-17 -1.67028788e+00]]]]
# Quadrupol moment:
#
#  [[ 4.09663845e-17  1.02419267e+00]
#  [ 1.02419267e+00 -4.09663845e-17]]
#
#
# Octupolpol moment:
#
#  [[[-8.65744485 -1.5038048 ]
#   [-1.5038048  -1.5038048 ]]
#
#  [[-1.5038048  -1.5038048 ]
#   [-1.5038048  -8.65744485]]]
#
#
# Hexadecapol moment:
#
#  [[[[-2.07030322e+00  3.27731076e-16]
#    [ 0.00000000e+00  2.07030322e+00]]
#
#   [[ 0.00000000e+00  2.07030322e+00]
#    [ 2.07030322e+00  1.63865538e-16]]]
#
#
#  [[[ 0.00000000e+00  2.07030322e+00]
#    [ 2.07030322e+00  1.63865538e-16]]
#
#   [[ 2.07030322e+00  1.63865538e-16]
#    [ 1.63865538e-16 -2.07030322e+00]]]]
# Quadrupol moment:
#
#  [[2.06698122e-16 1.02419267e+00]
#  [1.02419267e+00 0.00000000e+00]]
#
#
# Octupolpol moment:
#
#  [[[-12.19341829  -2.68246261]
#   [ -2.68246261  -2.68246261]]
#
#  [[ -2.68246261  -2.68246261]
#   [ -2.68246261 -12.19341829]]]
#
#
# Hexadecapol moment:
#
#  [[[[-3.15430404e+00 -1.83731664e-16]
#    [-2.75597496e-16  3.15430404e+00]]
#
#   [[-9.18658318e-17  3.15430404e+00]
#    [ 3.15430404e+00 -9.18658318e-17]]]
#
#
#  [[[ 0.00000000e+00  3.15430404e+00]
#    [ 3.15430404e+00  0.00000000e+00]]
#
#   [[ 3.15430404e+00  0.00000000e+00]
#    [ 0.00000000e+00 -3.15430404e+00]]]]
# Quadrupol moment:
#
#  [[-6.95970846e-17  4.05630901e+00]
#  [ 4.05630901e+00  4.63980564e-17]]
#
#
# Octupolpol moment:
#
#  [[[-36.64141307  -1.32111082]
#   [ -1.32111082  -1.32111082]]
#
#  [[ -1.32111082  -1.32111082]
#   [ -1.32111082 -36.64141307]]]
#
#
# Hexadecapol moment:
#
#  [[[[-2.47772961e+01 -7.42368903e-16]
#    [-3.71184451e-16  2.47772961e+01]]
#
#   [[ 7.42368903e-16  2.47772961e+01]
#    [ 2.47772961e+01 -1.48473781e-15]]]
#
#
#  [[[ 7.42368903e-16  2.47772961e+01]
#    [ 2.47772961e+01 -1.48473781e-15]]
#
#   [[ 2.47772961e+01 -1.48473781e-15]
#    [-1.48473781e-15 -2.47772961e+01]]]]
# Quadrupol moment:
#
#  [[ 1.63865538e-16  4.05630901e+00]
#  [ 4.05630901e+00 -1.63865538e-16]]
#
#
# Octupolpol moment:
#
#  [[[-41.65624191  -2.99272043]
#   [ -2.99272043  -2.99272043]]
#
#  [[ -2.99272043  -2.99272043]
#   [ -2.99272043 -41.65624191]]]
#
#
# Hexadecapol moment:
#
#  [[[[-2.51773115e+01 -6.55462152e-16]
#    [-6.55462152e-16  2.51773115e+01]]
#
#   [[ 0.00000000e+00  2.51773115e+01]
#    [ 2.51773115e+01  6.55462152e-16]]]
#
#
#  [[[-1.31092430e-15  2.51773115e+01]
#    [ 2.51773115e+01  0.00000000e+00]]
#
#   [[ 2.51773115e+01  6.55462152e-16]
#    [ 6.55462152e-16 -2.51773115e+01]]]]
# Quadrupol moment:
#
#  [[ 2.29664580e-16  4.05630901e+00]
#  [ 4.05630901e+00 -4.59329159e-17]]
#
#
# Octupolpol moment:
#
#  [[[-48.69317915  -5.33836618]
#   [ -5.33836618  -5.33836618]]
#
#  [[ -5.33836618  -5.33836618]
#   [ -5.33836618 -48.69317915]]]
#
#
# Hexadecapol moment:
#
#  [[[[-2.62613123e+01  0.00000000e+00]
#    [ 0.00000000e+00  2.62613123e+01]]
#
#   [[-7.34926655e-16  2.62613123e+01]
#    [ 2.62613123e+01 -1.46985331e-15]]]
#
#
#  [[[-7.34926655e-16  2.62613123e+01]
#    [ 2.62613123e+01 -1.46985331e-15]]
#
#   [[ 2.62613123e+01 -1.46985331e-15]
#    [-1.46985331e-15 -2.62613123e+01]]]]

# %%
#UPWARDS ELLIPSES
cen = 150

ratio_data_ell = np.array([["Ellipse Ratio, x:y", "Offset", "Quad Value", "Hexa Value", "Hexa:Quad Ratio"]])

for offset in range(5):
    adder = 1.1
    for size in range(5):
        print(cen)
        nx=500
        ny=500
        x=np.outer(np.linspace(-5,5,nx),np.ones(ny))
        y=np.outer(np.ones(nx),np.linspace(-5,5,ny))
        img=np.zeros((500, 500))

        ell_a = 30
        ell_b = 30**adder

        for row in range(nx):
            for col in range(ny):
                if ((((col-cen)**2)/(ell_a**2))+(((row-250)**2)/(ell_b**2))) <= 1:
                    img[row, col]=1

        #plt.imshow(img)
        #plt.show()





        # Quadruple moment:
        rsqr=x**2 + y**2
        q2=np.zeros([2,2])
        xy=[x,y]
        for i in [0,1]:
            for j in [0,1]:
                if i==j:
                    dij=1
                else:
                    dij=0
                q2[i,j]=1./2.*np.sum(img*(2*xy[i]*xy[j] - rsqr*dij))
        #print("\n\nQuadrupol moment:\n\n",q2/np.sum(img))
        q2_norm = q2/np.sum(img)


        # Octupole moment:

        q3=np.zeros([2,2,2])
        xy=[x,y]
        for i in [0,1]:
            for j in [0,1]:
                if i==j:
                    dij=1
                else:
                    dij=0
                for k in [0,1]:
                    if i==k:
                        dik=1
                    else:
                        dik=0
                    if j==k:
                        djk=1
                    else:
                        djk=0
                    q3[i,j,k]=1./2.*np.sum(img*(4*xy[i]*xy[j]*xy[k])) - np.sum(img*(rsqr*(xy[i]*djk + xy[j]*dik + xy[k]*dij)))
        #print("\n\nOctupolpol moment:\n\n",q3/np.sum(img))

        # Hexadecapole moment:

        q4=np.zeros([2,2,2,2])
        xy=[x,y]
        for i in [0,1]:
            for j in [0,1]:
                if i==j:
                    dij=1
                else:
                    dij=0
                for k in [0,1]:
                    if i==k:
                        dik=1
                    else:
                        dik=0
                    if j==k:
                        djk=1
                    else:
                        djk=0
                    for l in [0,1]:
                        if i==l:
                            dil=1
                        else:
                            dil=0
                        if j==l:
                            djl=1
                        else:
                            djl=0
                        if k==l:
                            dkl=1
                        else:
                            dkl=0
                        q4[i,j,k,l]=1./8.*np.sum(img*(24*xy[i]*xy[j]*xy[k]*xy[l] - 
                                               4*rsqr*(xy[k]*xy[l]*dij + xy[j]*xy[l]*dik + xy[j]*xy[k]*dil + xy[i]*xy[l]*djk + xy[i]*xy[k]*djl + xy[i]*xy[j]*dkl)) +
                                               img*(dij*dkl + dik*djl + dil*djk)*rsqr**2)

        #print("\n\nHexadecapol moment:\n\n",q4/np.sum(img))
        q4_norm =q4/np.sum(img)
    
        quad_val = q2_norm[0,0]
        hexa_val = q4_norm[0,0,0,0]
        
        
        dis_data = np.array([round(ell_a/ell_b, 4), cen, round(quad_val, 4), round(hexa_val, 4), round(hexa_val/quad_val, 4)])
        ratio_data_ell = np.vstack([ratio_data_ell, dis_data])

        adder += 0.1

        #print("\n\n")
    
    cen += 50
    
data_table = pd.DataFrame(ratio_data_ell)
        
print(data_table)
# Out:
# 150
# 150
# 150
# 150
# 150
# 200
# 200
# 200
# 200
# 200
# 250
# 250
# 250
# 250
# 250
# 300
# 300
# 300
# 300
# 300
# 350
# 350
# 350
# 350
# 350
#                      0       1           2           3                4
# 0   Ellipse Ratio, x:y  Offset  Quad Value  Hexa Value  Hexa:Quad Ratio
# 1               0.7117   150.0     -1.9437      5.1421          -2.6455
# 2               0.5065   150.0     -1.8558      3.6142          -1.9476
# 3               0.3605   150.0     -1.6834       0.755          -0.4485
# 4               0.2565   150.0     -1.3453      -4.337           3.2238
# 5               0.1826   150.0     -0.6757    -12.3995          18.3519
# 6               0.7117   200.0     -0.4478      0.1728          -0.3859
# 7               0.5065   200.0     -0.3598     -0.1704           0.4737
# 8               0.3605   200.0     -0.1874     -0.7086           3.7815
# 9               0.2565   200.0      0.1507     -1.2492          -8.2915
# 10              0.1826   200.0      0.8203     -0.2955          -0.3602
# 11              0.7117   250.0      0.0442      0.0056           0.1271
# 12              0.5065   250.0      0.1322       0.052           0.3932
# 13              0.3605   250.0      0.3046       0.277           0.9096
# 14              0.2565   250.0      0.6426      1.2333           1.9191
# 15              0.1826   250.0      1.3123       5.152            3.926
# 16              0.7117   300.0     -0.4678      0.1951          -0.4169
# 17              0.5065   300.0     -0.3799     -0.1641           0.4319
# 18              0.3605   300.0     -0.2075     -0.7334           3.5351
# 19              0.2565   300.0      0.1306     -1.3351         -10.2244
# 20              0.1826   300.0      0.8002     -0.5024          -0.6278
# 21              0.7117   350.0     -1.9839       5.368          -2.7058
# 22              0.5065   350.0     -1.8959      3.8084          -2.0087
# 23              0.3605   350.0     -1.7235      0.8869          -0.5146
# 24              0.2565   350.0     -1.3855     -4.3274           3.1234
# 25              0.1826   350.0     -0.7158    -12.6319           17.647

# %%
plt.rcParams["figure.figsize"] = (10,8)

colors = ["blue", "orange", "m", "green", "red", "purple"]
colorcount = 0
j = [1,6,11,16,21,26]
for x, i in enumerate([6,11,16,21,26]):

    offset_val = ratio_data_ell[i-1,1]
    print(offset_val)
    size_vals = ratio_data_ell[j[x]:i, 0]
    print(size_vals)
    ratio_vals = ratio_data_ell[j[x]:i, 4]
    print(ratio_vals)

    size_vals_flt = []
    ratio_vals_flt = []

    for i, ratio in enumerate(ratio_vals):
        dispers = float(size_vals[i])
        ratio = float(ratio)
        size_vals_flt.append(dispers)
        ratio_vals_flt.append(ratio)

    plt.plot(size_vals_flt, ratio_vals_flt, label="({}, 250)".format(offset_val), color=colors[colorcount], linewidth=3)
    colorcount += 1
    
#plt.yscale("log")
plt.xlabel("Ratio of ellipse x:y", fontsize=18)
plt.legend(title="Center of Ellipse")
plt.xticks(fontsize=14)
plt.ylabel("Ratio Hexa:Quad", fontsize=18)
plt.yticks(fontsize=14)
plt.title("Hexadecapol:Quadrupol Ratio\nvs. Lobe Separation", fontsize=24)
plt.show()


# plt.plot(dis_vals_flt[1:], ratio_vals_flt[1:], linewidth=3)
# plt.xlabel("Lobe Dispersion Factor\n(Scalar Change in Distance)", fontsize=18)
# plt.xticks(fontsize=14)
# plt.ylabel("Ratio Hexa:Quad", fontsize=18)
# plt.yticks(fontsize=14)
# plt.title("Hexadecapol:Quadrupol Ratio\nvs. Lobe Separation", fontsize=24)
# plt.show()

# plt.plot(dis_vals_flt[1:], ratio_vals_flt[1:], linewidth=3)
# plt.yscale("log")
# plt.xlabel("Lobe Dispersion Factor\n(Scalar Change in Distance)", fontsize=18)
# plt.xticks(fontsize=14)
# plt.ylabel("Ratio Hexa:Quad", fontsize=18)
# plt.yticks(fontsize=14)
# plt.title("Hexadecapol:Quadrupol Ratio\nvs. Lobe Separation", fontsize=24)
# plt.show()
# Out:
# 150.0
# ['0.7117' '0.5065' '0.3605' '0.2565' '0.1826']
# ['-2.6455' '-1.9476' '-0.4485' '3.2238' '18.3519']
# 200.0
# ['0.7117' '0.5065' '0.3605' '0.2565' '0.1826']
# ['-0.3859' '0.4737' '3.7815' '-8.2915' '-0.3602']
# 250.0
# ['0.7117' '0.5065' '0.3605' '0.2565' '0.1826']
# ['0.1271' '0.3932' '0.9096' '1.9191' '3.926']
# 300.0
# ['0.7117' '0.5065' '0.3605' '0.2565' '0.1826']
# ['-0.4169' '0.4319' '3.5351' '-10.2244' '-0.6278']
# 350.0
# ['0.7117' '0.5065' '0.3605' '0.2565' '0.1826']
# ['-2.7058' '-2.0087' '-0.5146' '3.1234' '17.647']

# %%
# #HORIZONTAL ELLIPSES
# cen = 250


# for offset in range(3):
#     adder = 15
#     for size in range(3):

#         nx=500
#         ny=500
#         x=np.outer(np.linspace(-5,5,nx),np.ones(ny))
#         y=np.outer(np.ones(nx),np.linspace(-5,5,ny))
#         img=np.zeros((500, 500))

#         ell_b = adder
#         ell_a = 3*adder

#         for row in range(nx):
#             for col in range(ny):
#                 if ((((col-cen)**2)/(ell_a**2))+(((row-cen)**2)/(ell_b**2))) <= 1:
#                     img[row, col]=1

#         plt.imshow(img)
#         plt.show()





#         # Quadruple moment:
#         rsqr=x**2 + y**2
#         q2=np.zeros([2,2])
#         xy=[x,y]
#         for i in [0,1]:
#             for j in [0,1]:
#                 if i==j:
#                     dij=1
#                 else:
#                     dij=0
#                 q2[i,j]=1./2.*np.sum(img*(2*xy[i]*xy[j] - rsqr*dij))
#         print("\n\nQuadrupol moment:\n\n",q2/np.sum(img))


#         # Octupole moment:

#         q3=np.zeros([2,2,2])
#         xy=[x,y]
#         for i in [0,1]:
#             for j in [0,1]:
#                 if i==j:
#                     dij=1
#                 else:
#                     dij=0
#                 for k in [0,1]:
#                     if i==k:
#                         dik=1
#                     else:
#                         dik=0
#                     if j==k:
#                         djk=1
#                     else:
#                         djk=0
#                     q3[i,j,k]=1./2.*np.sum(img*(4*xy[i]*xy[j]*xy[k])) - np.sum(img*(rsqr*(xy[i]*djk + xy[j]*dik + xy[k]*dij)))
#         print("\n\nOctupolpol moment:\n\n",q3/np.sum(img))

#         # Hexadecapole moment:

#         q4=np.zeros([2,2,2,2])
#         xy=[x,y]
#         for i in [0,1]:
#             for j in [0,1]:
#                 if i==j:
#                     dij=1
#                 else:
#                     dij=0
#                 for k in [0,1]:
#                     if i==k:
#                         dik=1
#                     else:
#                         dik=0
#                     if j==k:
#                         djk=1
#                     else:
#                         djk=0
#                     for l in [0,1]:
#                         if i==l:
#                             dil=1
#                         else:
#                             dil=0
#                         if j==l:
#                             djl=1
#                         else:
#                             djl=0
#                         if k==l:
#                             dkl=1
#                         else:
#                             dkl=0
#                         q4[i,j,k,l]=1./8.*np.sum(img*(24*xy[i]*xy[j]*xy[k]*xy[l] - 
#                                                4*rsqr*(xy[k]*xy[l]*dij + xy[j]*xy[l]*dik + xy[j]*xy[k]*dil + xy[i]*xy[l]*djk + xy[i]*xy[k]*djl + xy[i]*xy[j]*dkl)) +
#                                                img*(dij*dkl + dik*djl + dil*djk)*rsqr**2)

#         print("\n\nHexadecapol moment:\n\n",q4/np.sum(img))

#         adder += 25

#         print("\n\n")
    
#     cen += 25

# %%
#JET RESEMBLENSE
cen = 250

ratio_data = np.array([["Dispersion Value", "Quad Value", "Hexa Value", "Hexa:Quad Ratio"]])

adder = 0
for dispersion in range(9):

    nx=500
    ny=500
    x=np.outer(np.linspace(-5,5,nx),np.ones(ny))
    y=np.outer(np.ones(nx),np.linspace(-5,5,ny))
    img=np.zeros((500, 500))
    
    x2=x-adder
    x3=x+adder
    r2=np.sqrt(x2**2 + y**2)
    r3=np.sqrt(x3**2 + y**2)
    re=np.sqrt(x**2 + 10*y**2)


    img[re<1]=1

    img[r2<1.5]=1
    img[r3<1.5]=1

    plt.imshow(img)
    plt.imsave('img_{}.png'.format(adder), img)
    plt.show()





    # Quadruple moment:
    rsqr=x**2 + y**2
    q2=np.zeros([2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            q2[i,j]=1./2.*np.sum(img*(2*xy[i]*xy[j] - rsqr*dij))
    print("\n\nQuadrupol moment:\n\n",q2/np.sum(img))
    
    q2_norm = q2/np.sum(img)


    # Octupole moment:

    q3=np.zeros([2,2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            for k in [0,1]:
                if i==k:
                    dik=1
                else:
                    dik=0
                if j==k:
                    djk=1
                else:
                    djk=0
                q3[i,j,k]=1./2.*np.sum(img*(4*xy[i]*xy[j]*xy[k])) - np.sum(img*(rsqr*(xy[i]*djk + xy[j]*dik + xy[k]*dij)))
                
    q3_norm = q3/np.sum(img)
    print("\n\nOctupolpol moment:\n\n",q3_norm)
    
    
    

    # Hexadecapole moment:

    q4=np.zeros([2,2,2,2])
    xy=[x,y]
    for i in [0,1]:
        for j in [0,1]:
            if i==j:
                dij=1
            else:
                dij=0
            for k in [0,1]:
                if i==k:
                    dik=1
                else:
                    dik=0
                if j==k:
                    djk=1
                else:
                    djk=0
                for l in [0,1]:
                    if i==l:
                        dil=1
                    else:
                        dil=0
                    if j==l:
                        djl=1
                    else:
                        djl=0
                    if k==l:
                        dkl=1
                    else:
                        dkl=0
                    q4[i,j,k,l]=1./8.*np.sum(img*(24*xy[i]*xy[j]*xy[k]*xy[l] - 
                                           4*rsqr*(xy[k]*xy[l]*dij + xy[j]*xy[l]*dik + xy[j]*xy[k]*dil + xy[i]*xy[l]*djk + xy[i]*xy[k]*djl + xy[i]*xy[j]*dkl)) +
                                           img*(dij*dkl + dik*djl + dil*djk)*rsqr**2)

    print("\n\nHexadecapol moment:\n\n",q4/np.sum(img))
    q4_norm =q4/np.sum(img)
    
    quad_val = q2_norm[0,0]
    hexa_val = q4_norm[0,0,0,0]
    
    dis_data = np.array([adder, round(quad_val, 4), round(hexa_val, 4), round(hexa_val/quad_val, 4)])
    ratio_data = np.vstack([ratio_data, dis_data])

    print("\n\n")
    
    adder += 0.5
    
data_table = pd.DataFrame(ratio_data)
        
print(data_table)
# Out:
# Quadrupol moment:
#
#  [[ 6.46094781e-18  8.51785112e-19]
#  [ 8.51785112e-19 -6.46094781e-18]]
#
#
# Octupolpol moment:
#
#  [[[3.61813078e-16 2.31597217e-16]
#   [2.27899839e-16 2.48746491e-16]]
#
#  [[2.27899839e-16 2.48746491e-16]
#   [2.48746491e-16 6.86765943e-16]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 1.67246652e-03  6.05713857e-19]
#    [-8.83332709e-19 -1.67246652e-03]]
#
#   [[ 6.30951935e-20 -1.67246652e-03]
#    [-1.67246652e-03 -4.61225864e-18]]]
#
#
#  [[[ 4.66904432e-19 -1.67246652e-03]
#    [-1.67246652e-03 -4.81416326e-18]]
#
#   [[-1.67246652e-03 -3.53964035e-18]
#    [-2.45440303e-18  1.67246652e-03]]]]
# Quadrupol moment:
#
#  [[ 2.19123380e-01  1.68046989e-19]
#  [ 1.68046989e-19 -2.19123380e-01]]
#
#
# Octupolpol moment:
#
#  [[[1.31282315e-15 1.65725493e-16]
#   [1.63205901e-16 4.30200293e-16]]
#
#  [[1.63205901e-16 4.30200293e-16]
#   [4.30200293e-16 9.89137483e-16]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 1.47762079e-02  2.06553121e-18]
#    [-2.67094553e-18 -1.47762079e-02]]
#
#   [[-1.22863494e-18 -1.47762079e-02]
#    [-1.47762079e-02 -6.26781884e-18]]]
#
#
#  [[[-1.01495930e-18 -1.47762079e-02]
#    [-1.47762079e-02 -5.84046756e-18]]
#
#   [[-1.47762079e-02 -5.66240452e-18]
#    [-1.95869339e-18  1.47762079e-02]]]]
# Quadrupol moment:
#
#  [[ 5.74507955e-01 -2.03944528e-18]
#  [-2.03944528e-18 -5.74507955e-01]]
#
#
# Octupolpol moment:
#
#  [[[ 1.39226131e-15  8.61099118e-18]
#   [-2.71926037e-18  1.16746912e-15]]
#
#  [[-2.71926037e-18  1.16746912e-15]
#   [ 1.17109480e-15  1.43559952e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 4.18182967e-01  5.43852075e-18]
#    [-1.81284025e-18 -4.18182967e-01]]
#
#   [[-8.15778112e-18 -4.18182967e-01]
#    [-4.18182967e-01 -5.43852075e-18]]]
#
#
#  [[[-5.43852075e-18 -4.18182967e-01]
#    [-4.18182967e-01 -3.62568050e-18]]
#
#   [[-4.18182967e-01  2.71926037e-18]
#    [ 2.71926037e-18  4.18182967e-01]]]]
# Quadrupol moment:
#
#  [[ 1.12421770e+00 -4.15908274e-18]
#  [-4.15908274e-18 -1.12421770e+00]]
#
#
# Octupolpol moment:
#
#  [[[ 2.58115195e-15 -2.18597608e-16]
#   [-2.38876287e-16  1.19055634e-15]]
#
#  [[-2.38876287e-16  1.19055634e-15]
#   [ 1.19055634e-15  2.07644581e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 1.89730997e+00  3.29008651e-17]
#    [ 2.53767063e-17 -1.89730997e+00]]
#
#   [[ 2.82754610e-17 -1.89730997e+00]
#    [-1.89730997e+00  9.49657224e-18]]]
#
#
#  [[[ 2.93971530e-17 -1.89730997e+00]
#    [-1.89730997e+00  1.91758921e-17]]
#
#   [[-1.89730997e+00  2.23015058e-17]
#    [ 2.36122470e-17  1.89730997e+00]]]]
# Quadrupol moment:
#
#  [[ 1.91751232e+00 -5.46741934e-18]
#  [-5.46741934e-18 -1.91751232e+00]]
#
#
# Octupolpol moment:
#
#  [[[-1.18810542e-15 -5.74820811e-16]
#   [-5.73479262e-16  1.56557642e-15]]
#
#  [[-5.73479262e-16  1.56557642e-15]
#   [ 1.51607202e-15  3.04570734e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 5.75331856e+00 -1.17113663e-17]
#    [-3.18950420e-17 -5.75331856e+00]]
#
#   [[-3.07106108e-17 -5.75331856e+00]
#    [-5.75331856e+00 -1.99419550e-18]]]
#
#
#  [[[-8.33090280e-17 -5.75331856e+00]
#    [-5.75331856e+00  7.28787812e-18]]
#
#   [[-5.75331856e+00  8.93157865e-18]
#    [ 6.61106025e-18  5.75331856e+00]]]]
# Quadrupol moment:
#
#  [[ 2.92756401e+00  4.27733982e-18]
#  [ 4.27733982e-18 -2.92756401e+00]]
#
#
# Octupolpol moment:
#
#  [[[-1.54446139e-15 -1.02708002e-15]
#   [-9.82869061e-16  5.30079059e-15]]
#
#  [[-9.82869061e-16  5.30079059e-15]
#   [ 5.30003645e-15  4.18108936e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 1.36954479e+01 -2.30010119e-17]
#    [-4.90185500e-18 -1.36954479e+01]]
#
#   [[ 3.61983139e-17 -1.36954479e+01]
#    [-1.36954479e+01  1.79106240e-17]]]
#
#
#  [[[ 1.20661046e-17 -1.36954479e+01]
#    [-1.36954479e+01  2.99767287e-17]]
#
#   [[-1.36954479e+01  2.07386173e-17]
#    [ 5.67483983e-17  1.36954479e+01]]]]
# Quadrupol moment:
#
#  [[ 4.21002977e+00 -4.47718083e-19]
#  [-4.47718083e-19 -4.21002977e+00]]
#
#
# Octupolpol moment:
#
#  [[[ 9.26578493e-15 -1.53879527e-15]
#   [-1.54421501e-15  2.11134422e-15]]
#
#  [[-1.54421501e-15  2.11134422e-15]
#   [ 2.01482563e-15  5.72071194e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 2.83530177e+01  1.27434705e-16]
#    [ 3.54875491e-17 -2.83530177e+01]]
#
#   [[-5.65538631e-19 -2.83530177e+01]
#    [-2.83530177e+01  2.27158017e-17]]]
#
#
#  [[[-1.03116544e-16 -2.83530177e+01]
#    [-2.83530177e+01  3.47806258e-17]]
#
#   [[-2.83530177e+01  4.08130379e-17]
#    [-2.55434948e-17  2.83530177e+01]]]]
# Quadrupol moment:
#
#  [[ 5.72705556e+00  3.39287172e-18]
#  [ 3.39287172e-18 -5.72705556e+00]]
#
#
# Octupolpol moment:
#
#  [[[ 2.70223383e-14 -2.11564401e-15]
#   [-2.10810430e-15  8.05241555e-16]]
#
#  [[-2.10810430e-15  8.05241555e-16]
#   [ 8.05241555e-16  7.61511209e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 5.24994504e+01  1.20635439e-17]
#    [-3.01588598e-17 -5.24994504e+01]]
#
#   [[-1.80953159e-17 -5.24994504e+01]
#    [-5.24994504e+01  1.20635439e-16]]]
#
#
#  [[[-7.84130354e-17 -5.24994504e+01]
#    [-5.24994504e+01  1.08571895e-16]]
#
#   [[-5.24994504e+01  1.38730755e-16]
#    [ 1.38730755e-16  5.24994504e+01]]]]
# Quadrupol moment:
#
#  [[ 6.82282699e+00 -5.85773072e-18]
#  [-5.85773072e-18 -6.82282699e+00]]
#
#
# Octupolpol moment:
#
#  [[[ 1.37104371e-14 -2.53723422e-15]
#   [-2.48367782e-15  2.06192121e-15]]
#
#  [[-2.48367782e-15  2.06192121e-15]
#   [ 2.06192121e-15  8.89433648e-15]]]
#
#
# Hexadecapol moment:
#
#  [[[[ 7.06648622e+01 -1.87447383e-16]
#    [ 2.67781976e-16 -7.06648622e+01]]
#
#   [[-5.35563951e-17 -7.06648622e+01]
#    [-7.06648622e+01  1.07112790e-16]]]
#
#
#  [[[-5.35563951e-17 -7.06648622e+01]
#    [-7.06648622e+01 -2.67781976e-17]]
#
#   [[-7.06648622e+01  5.35563951e-17]
#    [-2.67781976e-17  7.06648622e+01]]]]
#
#
#
#                   0           1           2                   3
# 0  Dispersion Value  Quad Value  Hexa Value     Hexa:Quad Ratio
# 1               0.0         0.0      0.0017  258857767085428.03
# 2               0.5      0.2191      0.0148              0.0674
# 3               1.0      0.5745      0.4182              0.7279
# 4               1.5      1.1242      1.8973              1.6877
# 5               2.0      1.9175      5.7533              3.0004
# 6               2.5      2.9276     13.6954              4.6781
# 7               3.0        4.21      28.353              6.7346
# 8               3.5      5.7271     52.4995              9.1669
# 9               4.0      6.8228     70.6649             10.3571

# %%
plt.rcParams["figure.figsize"] = (10,8)


dis_vals = ratio_data[1:, 0]
ratio_vals = ratio_data[1:, 3]

dis_vals_flt = []
ratio_vals_flt = []

for i, ratio in enumerate(ratio_vals):
    dispers = float(dis_vals[i])
    ratio = float(ratio)
    dis_vals_flt.append(dispers)
    ratio_vals_flt.append(ratio)


plt.plot(dis_vals_flt, ratio_vals_flt, linewidth=3)
plt.yscale("log")
plt.xlabel("Lobe Dispersion Factor\n(Scalar Change in Distance)", fontsize=18)
plt.xticks(fontsize=14)
plt.ylabel("Ratio Hexa:Quad", fontsize=18)
plt.yticks(fontsize=14)
plt.title("Hexadecapol:Quadrupol Ratio\nvs. Lobe Separation", fontsize=24)
plt.show()


plt.plot(dis_vals_flt[1:], ratio_vals_flt[1:], linewidth=3)
plt.xlabel("Lobe Dispersion Factor\n(Scalar Change in Distance)", fontsize=18)
plt.xticks(fontsize=14)
plt.ylabel("Ratio Hexa:Quad", fontsize=18)
plt.yticks(fontsize=14)
plt.title("Hexadecapol:Quadrupol Ratio\nvs. Lobe Separation", fontsize=24)
plt.show()

plt.plot(dis_vals_flt[1:], ratio_vals_flt[1:], linewidth=3)
plt.yscale("log")
plt.xlabel("Lobe Dispersion Factor\n(Scalar Change in Distance)", fontsize=18)
plt.xticks(fontsize=14)
plt.ylabel("Ratio Hexa:Quad", fontsize=18)
plt.yticks(fontsize=14)
plt.title("Hexadecapol:Quadrupol Ratio\nvs. Lobe Separation", fontsize=24)
plt.show()
