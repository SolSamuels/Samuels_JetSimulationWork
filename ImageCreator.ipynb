# %%
import matplotlib.pyplot as plt
from astropy.visualization import astropy_mpl_style

astropy_mpl_style['axes.grid'] = False
plt.style.use(astropy_mpl_style)

# %%
from astropy.utils.data import get_pkg_data_filename
from astropy.io import fits
import glob
import matplotlib.colors as col

# %% [markdown]
# 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r'
#
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
path = '**/Group_L438_rc3_beta07*nu=30.0_los=0.00_1.00_0.00_*Myr.fits.gz'

# Determines if there are any files in device
total_files = len(glob.glob(path, recursive=True))

if total_files > 0:
    file_count = 0

    for file in sorted(glob.glob(path, recursive=True)):

        file_count += 1
                                             
        try:
            print("{}\n".format("_"*100))
            print("File Number {}\n".format(file_count))
            print("File Name: {}".format(file))
            
            fits_image_hdul = fits.open(file)
            

            #Displays FITS Image title, time index, and pixel size
            sim_title = fits_image_hdul[0].header['OBJECT']
            sim_time = fits_image_hdul[0].header['TIME']
            sim_time = round(float(sim_time[:-4]), 1)
            print("Simulation Title: {}".format(sim_title))
            print("Time index: {}".format(sim_time))
            
            #fits.info(file)
            #print(image_data.shape)
            image_data = fits.getdata(file, ext=0)
            for i in range(image_data.shape[0]):
                for j in range(image_data.shape[1]):
                    if image_data[i, j] == 0:
                        image_data[i, j] = 1e-12
            
            
            plt.figure()
            plt.imshow(image_data, cmap='hot', norm=col.LogNorm())
            plt.clim(10e-11, 1e2) 
            plt.colorbar()
            plt.show()
            
        except OSError:
            print("Error with file: {}".format(file))
            print("Empty or corrupt FITS file")
            
    
else:
    print("ERROR: Could not find any necessary files on your device")
    print("Program intakes files of the name: {}".format(path))
# Out:
# ____________________________________________________________________________________________________
#
# File Number 1
#
# File Name: Jet Simulation Data/Group_L430_rc3_beta07/fits/nu=30.0MHz/Group_L438_rc3_beta07_0020_nu=30.0_los=0.00_1.00_0.00_1.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc3_beta07 - 1.0 Myr - 30 MHz
# Time index: 1.0
# ____________________________________________________________________________________________________
#
# File Number 2
#
# File Name: Jet Simulation Data/Group_L430_rc3_beta07/fits/nu=30.0MHz/Group_L438_rc3_beta07_0040_nu=30.0_los=0.00_1.00_0.00_2.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc3_beta07 - 2.0 Myr - 30 MHz
# Time index: 2.0
# ____________________________________________________________________________________________________
#
# File Number 3
#
# File Name: Jet Simulation Data/Group_L430_rc3_beta07/fits/nu=30.0MHz/Group_L438_rc3_beta07_0080_nu=30.0_los=0.00_1.00_0.00_4.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc3_beta07 - 4.0 Myr - 30 MHz
# Time index: 4.0
# ____________________________________________________________________________________________________
#
# File Number 4
#
# File Name: Jet Simulation Data/Group_L430_rc3_beta07/fits/nu=30.0MHz/Group_L438_rc3_beta07_0160_nu=30.0_los=0.00_1.00_0.00_8.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc3_beta07 - 8.0 Myr - 30 MHz
# Time index: 8.0
# ____________________________________________________________________________________________________
#
# File Number 5
#
# File Name: Jet Simulation Data/Group_L430_rc3_beta07/fits/nu=30.0MHz/Group_L438_rc3_beta07_0240_nu=30.0_los=0.00_1.00_0.00_12.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc3_beta07 - 12.0 Myr - 30 MHz
# Time index: 12.0
# ____________________________________________________________________________________________________
#
# File Number 6
#
# File Name: Jet Simulation Data/Group_L430_rc3_beta07/fits/nu=30.0MHz/Group_L438_rc3_beta07_0280_nu=30.0_los=0.00_1.00_0.00_14.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc3_beta07 - 14.0 Myr - 30 MHz
# Time index: 14.0
# ____________________________________________________________________________________________________
#
# File Number 7
#
# File Name: Jet Simulation Data/Group_L430_rc3_beta07/fits/nu=30.0MHz/Group_L438_rc3_beta07_0320_nu=30.0_los=0.00_1.00_0.00_16.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc3_beta07 - 16.0 Myr - 30 MHz
# Time index: 16.0
# ____________________________________________________________________________________________________
#
# File Number 8
#
# File Name: Jet Simulation Data/Group_L430_rc3_beta07/fits/nu=30.0MHz/Group_L438_rc3_beta07_0528_nu=30.0_los=0.00_1.00_0.00_32.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc3_beta07 - 32.0 Myr - 30 MHz
# Time index: 32.0
# ____________________________________________________________________________________________________
#
# File Number 9
#
# File Name: Jet Simulation Data/Group_L430_rc3_beta07/fits/nu=30.0MHz/Group_L438_rc3_beta07_0656_nu=30.0_los=0.00_1.00_0.00_64.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc3_beta07 - 64.0 Myr - 30 MHz
# Time index: 64.0
# ____________________________________________________________________________________________________
#
# File Number 10
#
# File Name: Jet Simulation Data/Group_L430_rc3_beta07/fits/nu=30.0MHz/Group_L438_rc3_beta07_0912_nu=30.0_los=0.00_1.00_0.00_128.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc3_beta07 - 128.0 Myr - 30 MHz
# Time index: 128.0
# ____________________________________________________________________________________________________
#
# File Number 11
#
# File Name: Jet Simulation Data/Group_L430_rc3_beta07/fits/nu=30.0MHz/Group_L438_rc3_beta07_1107_nu=30.0_los=0.00_1.00_0.00_176.8Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc3_beta07 - 176.8 Myr - 30 MHz
# Time index: 176.8

# %%
path = '**/Group_L438_rc100_beta07*nu=30.0_los=0.00_1.00_0.00_*Myr.fits.gz'

# Determines if there are any files in device
total_files = len(glob.glob(path, recursive=True))

if total_files > 0:
    file_count = 0

    for file in sorted(glob.glob(path, recursive=True)):

        file_count += 1
                                             
        try:
            print("{}\n".format("_"*100))
            print("File Number {}\n".format(file_count))
            print("File Name: {}".format(file))
            
            fits_image_hdul = fits.open(file)
            

            #Displays FITS Image title, time index, and pixel size
            sim_title = fits_image_hdul[0].header['OBJECT']
            sim_time = fits_image_hdul[0].header['TIME']
            sim_time = round(float(sim_time[:-4]), 1)
            print("Simulation Title: {}".format(sim_title))
            print("Time index: {}".format(sim_time))
            
            #fits.info(file)
            #print(image_data.shape)
            image_data = fits.getdata(file, ext=0)
            for i in range(image_data.shape[0]):
                for j in range(image_data.shape[1]):
                    if image_data[i, j] == 0:
                        image_data[i, j] = 1e-12
            
            
            plt.figure()
            plt.imshow(image_data, cmap='hot', norm=col.LogNorm())
            plt.clim(10e-11, 1e2) 
            plt.colorbar()
            plt.show()
            
        except OSError:
            print("Error with file: {}".format(file))
            print("Empty or corrupt FITS file")
            
    
else:
    print("ERROR: Could not find any necessary files on your device")
    print("Program intakes files of the name: {}".format(path))
# Out:
# ____________________________________________________________________________________________________
#
# File Number 1
#
# File Name: Jet Simulation Data/Group_L438_rc100_beta07/fits/nu=30.0MHz/Group_L438_rc100_beta07_0020_nu=30.0_los=0.00_1.00_0.00_1.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc100_beta07 - 1.0 Myr - 30 MHz
# Time index: 1.0
# ____________________________________________________________________________________________________
#
# File Number 2
#
# File Name: Jet Simulation Data/Group_L438_rc100_beta07/fits/nu=30.0MHz/Group_L438_rc100_beta07_0040_nu=30.0_los=0.00_1.00_0.00_2.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc100_beta07 - 2.0 Myr - 30 MHz
# Time index: 2.0
# ____________________________________________________________________________________________________
#
# File Number 3
#
# File Name: Jet Simulation Data/Group_L438_rc100_beta07/fits/nu=30.0MHz/Group_L438_rc100_beta07_0080_nu=30.0_los=0.00_1.00_0.00_4.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc100_beta07 - 4.0 Myr - 30 MHz
# Time index: 4.0
# ____________________________________________________________________________________________________
#
# File Number 4
#
# File Name: Jet Simulation Data/Group_L438_rc100_beta07/fits/nu=30.0MHz/Group_L438_rc100_beta07_0160_nu=30.0_los=0.00_1.00_0.00_8.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc100_beta07 - 8.0 Myr - 30 MHz
# Time index: 8.0
# ____________________________________________________________________________________________________
#
# File Number 5
#
# File Name: Jet Simulation Data/Group_L438_rc100_beta07/fits/nu=30.0MHz/Group_L438_rc100_beta07_0320_nu=30.0_los=0.00_1.00_0.00_16.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc100_beta07 - 16.0 Myr - 30 MHz
# Time index: 16.0
# ____________________________________________________________________________________________________
#
# File Number 6
#
# File Name: Jet Simulation Data/Group_L438_rc100_beta07/fits/nu=30.0MHz/Group_L438_rc100_beta07_0640_nu=30.0_los=0.00_1.00_0.00_32.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc100_beta07 - 32.0 Myr - 30 MHz
# Time index: 32.0
# ____________________________________________________________________________________________________
#
# File Number 7
#
# File Name: Jet Simulation Data/Group_L438_rc100_beta07/fits/nu=30.0MHz/Group_L438_rc100_beta07_1280_nu=30.0_los=0.00_1.00_0.00_64.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc100_beta07 - 64.0 Myr - 30 MHz
# Time index: 64.0
# ____________________________________________________________________________________________________
#
# File Number 8
#
# File Name: Jet Simulation Data/Group_L438_rc100_beta07/fits/nu=30.0MHz/Group_L438_rc100_beta07_2560_nu=30.0_los=0.00_1.00_0.00_128.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc100_beta07 - 128.0 Myr - 30 MHz
# Time index: 128.0
# ____________________________________________________________________________________________________
#
# File Number 9
#
# File Name: Jet Simulation Data/Group_L438_rc100_beta07/fits/nu=30.0MHz/Group_L438_rc100_beta07_5120_nu=30.0_los=0.00_1.00_0.00_256.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc100_beta07 - 256.0 Myr - 30 MHz
# Time index: 256.0
# ____________________________________________________________________________________________________
#
# File Number 10
#
# File Name: Jet Simulation Data/Group_L438_rc100_beta07/fits/nu=30.0MHz/Group_L438_rc100_beta07_6400_nu=30.0_los=0.00_1.00_0.00_320.0Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc100_beta07 - 320.0 Myr - 30 MHz
# Time index: 320.0
# ____________________________________________________________________________________________________
#
# File Number 11
#
# File Name: Jet Simulation Data/Group_L438_rc100_beta07/fits/nu=30.0MHz/Group_L438_rc100_beta07_7692_nu=30.0_los=0.00_1.00_0.00_384.2Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc100_beta07 - 384.2 Myr - 30 MHz
# Time index: 384.1
# ____________________________________________________________________________________________________
#
# File Number 12
#
# File Name: Jet Simulation Data/Group_L438_rc100_beta07/fits/nu=30.0MHz/Group_L438_rc100_beta07_8342_nu=30.0_los=0.00_1.00_0.00_448.2Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc100_beta07 - 448.2 Myr - 30 MHz
# Time index: 448.1
# ____________________________________________________________________________________________________
#
# File Number 13
#
# File Name: Jet Simulation Data/Group_L438_rc100_beta07/fits/nu=30.0MHz/Group_L438_rc100_beta07_8359_nu=30.0_los=0.00_1.00_0.00_510.7Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc100_beta07 - 510.7 Myr - 30 MHz
# Time index: 510.6
# ____________________________________________________________________________________________________
#
# File Number 14
#
# File Name: Jet Simulation Data/Group_L438_rc100_beta07/fits/nu=30.0MHz/Group_L438_rc100_beta07_8374_nu=30.0_los=0.00_1.00_0.00_585.7Myr.fits.gz
# Simulation Title: Simulation Group_L438_rc100_beta07 - 585.7 Myr - 30 MHz
# Time index: 585.7
