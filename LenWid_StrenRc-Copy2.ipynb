# %%
import astropy.io
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import time

from astropy.io import fits
from scipy.ndimage import gaussian_filter1d
from scipy.signal import argrelextrema

# %%
#This Function Takes FITS data and pixel size to display Jet Length Info
def jet_length(data, pixel_size):
    
    #Creates list of slice sums
    slice_vals = []
    for row in data:
        slice_sum = 0
        for element in row:
            slice_sum += element
        slice_vals.append(slice_sum)
        
    #Creates list of Cumulative Sum values
    cul_vals = []
    movingsum = 0
    for element in slice_vals:
        movingsum += element
        cul_vals.append(movingsum)
        
    #Normalizes the Cumulative Values and creates list
    max_val = cul_vals[-1]
    norm_cul_vals = []
    norm = 0
    for element in cul_vals:
        norm = element / max_val
        norm_cul_vals.append(norm)
        
    #Edits the Normalizes Values to Exclude zeros and repeating terms
    final_reached = False
    norm_cul_vals_edit = []
    for element in norm_cul_vals:
        if element != 0 and final_reached is False:
            norm_cul_vals_edit.append(element)
        if element == 1:
            final_reached = True
        
    #Creates Value Headers for x-axis of histogram
    x_vals = []
    for x in range(len(norm_cul_vals_edit)):
        x_vals.append(x)
        
    x_vals_med = round(len(x_vals) / 2)
    x_vals_Q1 = round(np.median(x_vals[:x_vals_med]))
    x_vals_Q3 = round(np.median(x_vals[x_vals_med:]))
        
    smooth = gaussian_filter1d(norm_cul_vals_edit, 10)
    d1 = np.gradient(smooth)
    smooth_d1 = gaussian_filter1d(d1, 50)
    d2 = np.gradient(smooth_d1)
    smooth_d2 = gaussian_filter1d(d2, 100)
    d3 = np.gradient(smooth_d2)
    smooth_d3 = gaussian_filter1d(d3, 300)
    infls = np.where(np.diff(np.sign(smooth_d2)))[0]
    
    # for local maxima
    maxima_d2 = argrelextrema(smooth_d2, np.greater)
    # for local minima
    minima_d2 = argrelextrema(smooth_d2, np.less)
    
    
    norm_smooth_d1 = smooth_d1 / np.max(smooth_d1)
    norm_smooth_d2 = smooth_d2 / np.max(smooth_d2)
    norm_smooth_d3 = smooth_d3 / np.max(smooth_d3)
    
    #edited normalized cumulative histogram of data
#     plt.plot(x_vals, norm_cul_vals_edit, color='b', label = "raw")
#     #plt.plot(norm_smooth_d1, label='1st derivative', color = "g")
#     #plt.plot(norm_smooth_d2, label='2nd derivative', color = "orange")
#     #plt.plot(norm_smooth_d3, label='3rd derivative', color = "r")
#     labelcount = 0
#     for i, infl in enumerate(infls, 1):
#         if labelcount == 0:
#             plt.axvline(x=infl, color='k', linestyle='dashed', label="Inflection Points")
#         else:
#             plt.axvline(x=infl, color='k', linestyle='dashed')
#         labelcount += 1
        
#     plt.show()
        

    min_lst = []
    max_lst = []
    if len(maxima_d2) > 0:
        for element in maxima_d2:
            for index in element:
                try:
                    #plt.axvline(x=index, color='r', linestyle='dashed')
                    max_lst.append(index)
                except ValueError:
                    print("Did not graph: {}".format(index))
    if len(minima_d2) > 0:
        for element in minima_d2:
            for index in element:
                try:
                    #plt.axvline(x=index, color='y', linestyle='dashed')
                    min_lst.append(index)
                except ValueError:
                    print("Did not graph: {}".format(index))
                    
    
    #Determines and prints length of jet in pixels. Estimates to 0.98
    pixel_count = 0
    for element in norm_cul_vals_edit:
        if element >= 0.02 and element <= 0.98:
            pixel_count += 1
    

    #Converts pixel size to cm and prints
    jet_size_cm = pixel_size * pixel_count
    
    
    #Converts cm size to kpc and prints
    jet_size_kpc = round((jet_size_cm * 3.24077928967e-19) / 1e3, 4)
    
    lobe_dist_kpc = 0.0
    

    max_lst = sorted(max_lst)
    min_lst = sorted(min_lst)
    
    if (len(max_lst) + len(min_lst)) > 3:
        
        main_max = []
        main_min = []
        for point in max_lst:
            if point > x_vals_med and point < x_vals_Q3:
                main_max.append(point)
        for point in min_lst:
            if point > x_vals_Q1 and point < x_vals_med:
                main_min.append(point)
        
        try:
            if len(main_max) == 0:
                for point in max_lst:
                    if point > x_vals_med:
                        main_max.append(point)
            if len(main_min) == 0:
                for point in min_lst:
                    if point < x_vals_med:
                        main_min.append(point)
  
            slice_vals_edit = []
            flag = False
            for element in slice_vals:
                if flag is True:
                    slice_vals_edit.append(element)
                if element != 0 and flag is False:
                    flag = True
                    slice_vals_edit.append(element)

            for i in range(max(main_min), min(main_max)):
                slice_vals_edit[i] = float(0)

            lobe_dist = min(main_max) - max(main_min)

            cul_vals = []
            movingsum = 0
            for element in slice_vals_edit:
                movingsum += element
                cul_vals.append(movingsum)

            #Normalizes the Cumulative Values and creates list
            max_val = cul_vals[-1]
            norm_cul_vals = []
            norm = 0
            for element in cul_vals:
                norm = element / max_val
                norm_cul_vals.append(norm)

            #Edits the Normalizes Values to Exclude zeros and repeating terms
            final_reached = False
            norm_cul_vals_edit = []
            for element in norm_cul_vals:
                if element != 0 and final_reached is False:
                    norm_cul_vals_edit.append(element)
                if element == 1:
                    final_reached = True


            #Determines and prints length of jet in pixels. Estimates to 0.98
            pixel_count = 0
            for element in norm_cul_vals_edit:
                if element >= 0.02 and element <= 0.98:
                    pixel_count += 1

            #Converts pixel size to cm and prints
            jet_size_cm = pixel_size * pixel_count

            #Converts cm size to kpc and prints
            jet_size_kpc = round((jet_size_cm * 3.24077928967e-19) / 1e3, 4)

            lobe_dist_cm = lobe_dist * pixel_size
            lobe_dist_kpc = round((lobe_dist_cm * 3.24077928967e-19) / 1e3, 4)
        
        except ValueError:
            p=0

    jet_len_info = [jet_size_kpc, lobe_dist_kpc]
    
    return jet_len_info

# %%
def progress(file_count, total_files):
    print("\tFiles Completed: {}/{}".format(file_count, total_files), end="\r") 
    time.sleep(1)

# %%
#Main Calling Block of Code

print("\nJET LENGTH AND WIDTH DETERMINING PROGRAM:")
print("{}\n".format("_"*100))

strengths = [430, 438, 446]
rc_vals = [3, 10, 30, 100]
nu_count = 0

for value in strengths: 
    for rc in rc_vals:

        path = '**/Group_L{}_rc{}_*nu=30.0*0.00_1.00_0.00*Myr.fits*'.format(value, rc)
        nu_count += 1

        # Determines if there are any files in device
        total_files = len(glob.glob(path, recursive=True))

        if total_files > 0:

            print("\nTRYING STRENGTH VALUE L{}, rc{}...".format(value, rc))
            file_count = 0
            progress(file_count, total_files)
            jet_dim_data = np.array([["Time (Myr)", "Jet Length (kpc)", "Lobe Distance (kpc)"]])

            for file in sorted(glob.glob(path, recursive=True)):

                file_count += 1

                try:
                    fits_image_hdul = fits.open(file)

                    #Displays FITS Image title, time index, and pixel size
                    sim_title = fits_image_hdul[0].header['OBJECT']
                    nu_value = int(sim_title[-7:-4])
                    sim_time = fits_image_hdul[0].header['TIME']
                    sim_time = round(float(sim_time[:-4]), 1)
                    pixel = fits_image_hdul[0].header['CDELT1']
                    pixel_size = float(pixel[:-3])

                    #Difines Data From FITS image and records image dimensions
                    data =  fits_image_hdul[0].data
                    length = len(data[0])
                    width = len(data)

                    #Calls jet_length function
                    jet_len_info = jet_length(data, pixel_size)
                    jet_len = jet_len_info[0]
                    lobe_dist_kpc = jet_len_info[1]

                    #Calls jet_width function


                    file_data = np.array([float(sim_time), jet_len, lobe_dist_kpc])
                    jet_dim_data = np.vstack([jet_dim_data, file_data])

                    progress(file_count, total_files)

                except OSError:
                    print("Error with file: {}".format(file))
                    print("Empty or corrupt FITS file")

            print("\n\n TABLE OF JET LENGTHS AND WIDTHS OVER TIME FOR L{}".format(str(value)))
            data_table = pd.DataFrame(jet_dim_data)


            print(data_table)
            with open("data_table_L{}_rc{}.npy".format(value, rc), "wb") as open_file:
                np.save(open_file, jet_dim_data)
# Out:
# JET LENGTH AND WIDTH DETERMINING PROGRAM:
# ____________________________________________________________________________________________________
#
#
# TRYING STRENGTH VALUE L430, rc3...
# 	Files Completed: 11/11
#
#  TABLE OF JET LENGTHS AND WIDTHS OVER TIME FOR L430
#              0                 1                    2
# 0   Time (Myr)  Jet Length (kpc)  Lobe Distance (kpc)
# 1        2e+00           19.7688                  0.0
# 2        4e+00           34.4171                  0.0
# 3        8e+00           60.4081                  0.0
# 4        1e+01           62.1581                  0.0
# 5      1.2e+01            64.686              16.7872
# 6      1.4e+01           68.3156              17.7595
# 7      1.6e+01           73.5657              19.5095
# 8     3.28e+01            98.066              38.6949
# 9     7.29e+01          132.7423              60.0192
# 10   1.328e+02          169.8168               93.853
# 11   1.971e+02          195.4838              90.5474
#
# TRYING STRENGTH VALUE L430, rc10...
# 	Files Completed: 11/11
#
#  TABLE OF JET LENGTHS AND WIDTHS OVER TIME FOR L430
#              0                 1                    2
# 0   Time (Myr)  Jet Length (kpc)  Lobe Distance (kpc)
# 1        1e+00            7.1945                  0.0
# 2        2e+00           13.0279                  0.0
# 3        4e+00           16.4632                  0.0
# 4        8e+00           25.2133                  0.0
# 5      1.6e+01           40.5097                  0.0
# 6        2e+01           44.5931                  0.0
# 7      2.4e+01           52.9543                  0.0
# 8      2.8e+01           55.2229                  0.0
# 9      3.2e+01            60.084                  0.0
# 10     6.4e+01            89.964                  0.0
# 11       1e+02          113.6865              57.7507
#
# TRYING STRENGTH VALUE L430, rc30...
# 	Files Completed: 11/11
#
#  TABLE OF JET LENGTHS AND WIDTHS OVER TIME FOR L430
#              0                 1                    2
# 0   Time (Myr)  Jet Length (kpc)  Lobe Distance (kpc)
# 1        1e+00            7.7454                  0.0
# 2        2e+00           11.3084                  0.0
# 3        4e+00           15.5837                  0.0
# 4        8e+00           21.8074                  0.0
# 5      1.6e+01           30.1664                  0.0
# 6      3.2e+01           41.9629                  0.0
# 7      6.4e+01           59.9844                  0.0
# 8        8e+01           69.6768              39.2134
# 9     1.12e+02           88.7974              47.1857
# 10   1.276e+02           98.4549              51.4636
# 11   2.376e+02          146.5125               99.058
#
# TRYING STRENGTH VALUE L438, rc3...
# 	Files Completed: 11/11
#
#  TABLE OF JET LENGTHS AND WIDTHS OVER TIME FOR L438
#              0                 1                    2
# 0   Time (Myr)  Jet Length (kpc)  Lobe Distance (kpc)
# 1        1e+00           13.3632                  0.0
# 2        2e+00           32.5698                  0.0
# 3        4e+00           74.2836                  0.0
# 4        8e+00          138.2911                  0.0
# 5      1.2e+01          193.6366                  0.0
# 6      1.4e+01          230.9055             129.9552
# 7      1.6e+01          281.9478              97.8715
# 8      3.2e+01          413.6855             114.7236
# 9      6.4e+01          539.2657             153.6129
# 10    1.28e+02          691.4203             243.3825
# 11   1.768e+02          779.2454             289.2396
#
# TRYING STRENGTH VALUE L438, rc10...
# 	Files Completed: 9/9
#
#  TABLE OF JET LENGTHS AND WIDTHS OVER TIME FOR L438
#             0                 1                    2
# 0  Time (Myr)  Jet Length (kpc)  Lobe Distance (kpc)
# 1       1e+00            9.3193                  0.0
# 2       2e+00           16.9225                  0.0
# 3       4e+00           32.6513                  0.0
# 4       8e+00           47.7119                  0.0
# 5     1.6e+01           80.5334                  0.0
# 6     3.2e+01          133.7517                  0.0
# 7    6.41e+01          305.1804              70.8252
# 8   1.281e+02          438.0526              49.4288
# 9   2.546e+02               0.0                  0.0
#
# TRYING STRENGTH VALUE L438, rc30...
# 	Files Completed: 14/14
#
#  TABLE OF JET LENGTHS AND WIDTHS OVER TIME FOR L438
#              0                 1                    2
# 0   Time (Myr)  Jet Length (kpc)  Lobe Distance (kpc)
# 1        1e+00            8.8289                  0.0
# 2        2e+00           15.5557                  0.0
# 3        4e+00           24.3058                  0.0
# 4      5.2e+00            29.005                  0.0
# 5     1.71e+01            49.746                  0.0
# 6      3.2e+01              74.7                  0.0
# 7      6.4e+01          104.3531                  0.0
# 8        8e+01          125.5802                  0.0
# 9      9.6e+01          145.1869                  0.0
# 10    1.12e+02          171.9233                  0.0
# 11    1.28e+02          200.6724              81.2091
# 12   2.719e+02          377.5508             114.8856
# 13   5.119e+02          533.0101             188.9601
# 14   5.419e+02          550.7704             195.7431
#
# TRYING STRENGTH VALUE L438, rc100...
# 	Files Completed: 14/14
#
#  TABLE OF JET LENGTHS AND WIDTHS OVER TIME FOR L438
#              0                 1                    2
# 0   Time (Myr)  Jet Length (kpc)  Lobe Distance (kpc)
# 1        1e+00            9.1558                  0.0
# 2        2e+00            15.631                  0.0
# 3        4e+00           22.9229                  0.0
# 4        8e+00            33.218                  0.0
# 5      1.6e+01           45.2089                  0.0
# 6      3.2e+01           61.8989                  0.0
# 7      6.4e+01           77.6167                  0.0
# 8     1.28e+02          103.0568                  0.0
# 9     2.56e+02          162.5251                  0.0
# 10     3.2e+02          208.2201                  0.0
# 11   3.841e+02          246.1372                  0.0
# 12   4.481e+02          289.0775             118.6125
# 13   5.106e+02          325.5363             140.8119
# 14   5.857e+02          362.3916             194.6477
#
# TRYING STRENGTH VALUE L446, rc3...
# 	Files Completed: 11/11
#
#  TABLE OF JET LENGTHS AND WIDTHS OVER TIME FOR L446
#              0                 1                    2
# 0   Time (Myr)  Jet Length (kpc)  Lobe Distance (kpc)
# 1        1e+00           16.2039                  0.0
# 2        2e+00           49.4219                  0.0
# 3        4e+00           141.379                  0.0
# 4        8e+00          300.5823                  0.0
# 5     1.31e+01          496.6494              36.0537
# 6     1.81e+01          707.7052             151.9115
# 7     3.31e+01          961.2962              274.656
# 8      6.3e+01          663.1445              69.6768
# 9    1.279e+02         1508.5828             455.3295
# 10   2.577e+02           815.056                  0.0
# 11   4.723e+02           39.2944             828.4242
#
# TRYING STRENGTH VALUE L446, rc10...
# 	Files Completed: 11/11
#
#  TABLE OF JET LENGTHS AND WIDTHS OVER TIME FOR L446
#              0                 1                    2
# 0   Time (Myr)  Jet Length (kpc)  Lobe Distance (kpc)
# 1        1e+00           11.3427                  0.0
# 2        2e+00           21.4702                  0.0
# 3        4e+00           44.5607                  0.0
# 4        8e+00           79.8042                  0.0
# 5      1.6e+01          157.5829                  0.0
# 6      3.2e+01          294.1007                  0.0
# 7      6.4e+01          556.6038             154.7472
# 8     7.91e+01          625.4704             191.6111
# 9    1.281e+02          799.6623             283.9733
# 10   2.601e+02          1056.089             356.8908
# 11   4.702e+02         1374.4955             447.2275
#
# TRYING STRENGTH VALUE L446, rc30...
# 	Files Completed: 11/11
#
#  TABLE OF JET LENGTHS AND WIDTHS OVER TIME FOR L446
#              0                 1                    2
# 0   Time (Myr)  Jet Length (kpc)  Lobe Distance (kpc)
# 1        1e+00           10.9376                  0.0
# 2        2e+00           18.6345                  0.0
# 3        4e+00           30.7874                  0.0
# 4        8e+00           49.0168                  0.0
# 5      1.6e+01           80.6144                  0.0
# 6      3.2e+01          122.3394                  0.0
# 7      6.4e+01          189.9907                  0.0
# 8    1.212e+02          349.5991                  0.0
# 9    2.561e+02          703.2491             190.3958
# 10   5.131e+02          969.3981             283.5682
# 11   7.731e+02          1056.494             326.5085
#
# TRYING STRENGTH VALUE L446, rc100...
# 	Files Completed: 13/13
#
#  TABLE OF JET LENGTHS AND WIDTHS OVER TIME FOR L446
#              0                 1                    2
# 0   Time (Myr)  Jet Length (kpc)  Lobe Distance (kpc)
# 1        1e+00           10.9376                  0.0
# 2        2e+00           18.2294                  0.0
# 3        4e+00           30.3823                  0.0
# 4        8e+00            45.776                  0.0
# 5      1.6e+01           71.7022                  0.0
# 6      3.2e+01           92.7673                  0.0
# 7      6.4e+01          122.7445                  0.0
# 8     1.28e+02          175.4072                  0.0
# 9     2.56e+02          275.4662                  0.0
# 10     3.2e+02          338.2563                  0.0
# 11    3.84e+02          418.4656                  0.0
# 12   5.121e+02          544.4509             202.1436
# 13   9.981e+02          792.7756               145.43

# %%
plt.rcParams["figure.figsize"] = (6,5)

for value in strengths:
    for rc in rc_vals:
        try:
            with open("data_table_L{}_rc{}.npy".format(value, rc), "rb") as open_file:
                current_freq = np.load(open_file)

                time_vals = []
                jet_len_vals = []

                for i in range(1, len(current_freq)):
                    if float(current_freq[i, 1]) != 0:
                        time_vals.append(float(current_freq[i, 0]))
                        jet_len_vals.append(float(current_freq[i, 1]))

                plt.plot(time_vals, jet_len_vals, label="L{}, rc{}".format(value, rc), linewidth=3)

        except:
            p = 0
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Time (Myr)", fontsize=14)
plt.ylabel("Jet Length (kpc)", fontsize=14)
plt.title("Jet Lengths for Varied Jet Strengths\nrc30, 30MHz", fontsize=18)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc=2, prop={'size': 10})
plt.show()
plt.savefig('Jet_Lengths_vs_Time.png')

# %%
# for value in strengths:
#     try:
#         with open("data_table_L{}.npy".format(str(value)), "rb") as open_file:
#             current_freq = np.load(open_file)
            
#             time_vals = []
#             jet_wid_vals = []

#             for i in range(1, len(current_freq)):
#                 time_vals.append(float(current_freq[i, 0]))
#                 jet_wid_vals.append(float(current_freq[i, 2]))
            
#             plt.plot(time_vals, jet_wid_vals, label="L{}".format(str(value)), linewidth=3)
        
#     except:
#         p = 0

# plt.xscale("log")
# plt.yscale("log")
# plt.xlabel("Time (Myr)", fontsize=14)
# plt.ylabel("Jet Width (kpc)", fontsize=14)
# plt.title("Jet Widths for Varied Jet Strengths\nrc30, 30MHz", fontsize=18)
# plt.xticks(fontsize=12)
# plt.yticks(fontsize=12)
# plt.legend(loc=2, prop={'size': 10})
# plt.show()
# plt.savefig('Jet_Widths_vs_Time.png')

# %%
plt.rcParams["figure.figsize"] = (7.5,6.5)


for value in strengths:
    for rc in rc_vals:
        try:
            with open("data_table_L{}_rc{}.npy".format(value, rc), "rb") as open_file:
                current_freq = np.load(open_file)

                time_vals = []
                lobe_vals = []

                for i in range(1, len(current_freq)):
                    lobe_dist = float(current_freq[i, 2])
                    if lobe_dist != 0:

                        time_vals.append(float(current_freq[i, 0]))
                        lobe_vals.append(lobe_dist)



                    prev_time = float(current_freq[i, 0])
                    prev_lobe = lobe_dist



                plt.scatter(time_vals, lobe_vals, label="L{}".format(str(value)), s=100, edgecolor = "k")
        except FileNotFoundError:
            p=0
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Time (Myr)", fontsize=14)
plt.ylabel("Lobe Separation (kpc)", fontsize=14)
plt.title("Lobe Separations for Varied Jet Strengths\nrc30, 30MHz", fontsize=18)
plt.xticks( fontsize=12)
plt.yticks(fontsize=12)
#plt.legend(loc=2, prop={'size': 10})
plt.show()
plt.savefig('Jet_Lengths_vs_Time.png')

# %%
plt.rcParams["figure.figsize"] = (7.5,6.5)

rc_vals = [3,10,30,100]
for value in strengths:
    time_vals = []
    lobe_vals = []
    for rc in rc_vals:
        try:
            with open("data_table_L{}_rc{}.npy".format(value, rc), "rb") as open_file:
                current_freq = np.load(open_file)


                for i in range(1, len(current_freq)):
                    lobe_dist = float(current_freq[i, 2])
                    if lobe_dist != 0:

                        time_vals.append(float(current_freq[i, 0]))
                        lobe_vals.append(lobe_dist)



                    prev_time = float(current_freq[i, 0])
                    prev_lobe = lobe_dist

        except FileNotFoundError:
            p=0

    plt.scatter(time_vals, lobe_vals, label="L{}".format(str(value)), s=100, edgecolor = "k")
        
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Time (Myr)", fontsize=14)
plt.ylabel("Lobe Separation (kpc)", fontsize=14)
plt.title("Lobe Separations for Varied Jet Strengths", fontsize=18)
plt.xticks( fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc=2, prop={'size': 10})
plt.show()
plt.savefig('Jet_Lengths_vs_Time.png')

# %%
plt.rcParams["figure.figsize"] = (7.5,6.5)


for rc in rc_vals:
    time_vals = []
    lobe_vals = []
    for value in strengths:
        try:
            with open("data_table_L{}_rc{}.npy".format(value, rc), "rb") as open_file:
                current_freq = np.load(open_file)


                for i in range(1, len(current_freq)):
                    lobe_dist = float(current_freq[i, 2])
                    if lobe_dist != 0:

                        time_vals.append(float(current_freq[i, 0]))
                        lobe_vals.append(lobe_dist)



                    prev_time = float(current_freq[i, 0])
                    prev_lobe = lobe_dist

        except FileNotFoundError:
            p=0

    plt.scatter(time_vals, lobe_vals, label="rc{}".format(rc), s=100, edgecolor = "k")
        
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Time (Myr)", fontsize=14)
plt.ylabel("Lobe Separation (kpc)", fontsize=14)
plt.title("Lobe Separations for Varied Densities", fontsize=18)
plt.xticks( fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc=2, prop={'size': 10})
plt.show()
plt.savefig('Jet_Lengths_vs_Time.png')

# %%
#Main Calling Block of Code

print("\nJET LENGTH AND WIDTH DETERMINING PROGRAM:")
print("{}\n".format("_"*100))

rc_vals = [3, 10, 30, 100]
nu_count = 0

for value in rc_vals: 
    path = '**/Group_L438_rc{}_*nu=30.0*0.00_1.00_0.00*Myr.fits*'.format(value)
    nu_count += 1

    # Determines if there are any files in device
    total_files = len(glob.glob(path, recursive=True))

    if total_files > 0:
        
        print("\nTRYING DENSITY RC{}...".format(str(value)))
        file_count = 0
        progress(file_count, total_files)
        jet_dim_data = np.array([["Time (Myr)", "Jet Length (kpc)", "Jet Width (kpc)", "Lobe Distance (kpc)"]])

        for file in sorted(glob.glob(path, recursive=True)):

            file_count += 1

            try:
                fits_image_hdul = fits.open(file)

                #Displays FITS Image title, time index, and pixel size
                sim_title = fits_image_hdul[0].header['OBJECT']
                nu_value = int(sim_title[-7:-4])
                sim_time = fits_image_hdul[0].header['TIME']
                sim_time = round(float(sim_time[:-4]), 1)
                pixel = fits_image_hdul[0].header['CDELT1']
                pixel_size = float(pixel[:-3])

                #Difines Data From FITS image and records image dimensions
                data =  fits_image_hdul[0].data
                length = len(data[0])
                width = len(data)

                #Calls jet_length function
                jet_len_info = jet_length(data, pixel_size)
                jet_len = jet_len_info[0]
                lobe_dist_kpc = jet_len_info[1]

                #Calls jet_width function
                jet_wid = jet_width(data, width, pixel_size)


                file_data = np.array([float(sim_time), jet_len, jet_wid, lobe_dist_kpc])
                jet_dim_data = np.vstack([jet_dim_data, file_data])
                
                progress(file_count, total_files)

            except OSError:
                print("Error with file: {}".format(file))
                print("Empty or corrupt FITS file")

        print("\n\n TABLE OF JET LENGTHS AND WIDTHS OVER TIME FOR L{}".format(str(value)))
        data_table = pd.DataFrame(jet_dim_data)
        
        
        print(data_table)
        with open("data_table_rc{}.npy".format(str(value)), "wb") as open_file:
            np.save(open_file, jet_dim_data)
# Out:
# JET LENGTH AND WIDTH DETERMINING PROGRAM:
# ____________________________________________________________________________________________________
#
#
# TRYING DENSITY RC3...
# 	Files Completed: 0/11
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 9>()
#      46 lobe_dist_kpc = jet_len_info[1]
#      48 #Calls jet_width function
# ---> 49 jet_wid = jet_width(data, width, pixel_size)
#      52 file_data = np.array([float(sim_time), jet_len, jet_wid, lobe_dist_kpc])
#      53 jet_dim_data = np.vstack([jet_dim_data, file_data])
#
# NameError: name 'jet_width' is not defined

# %%
plt.rcParams["figure.figsize"] = (6,5)

rc_colors = {3:"b", 10:"orange", 30:"green", 100:"red"}

for value in rc_vals:
        rc_met = False
        with open("data_table_rc{}.npy".format(str(value)), "rb") as open_file:
            current_freq = np.load(open_file)
            
            time_vals = []
            jet_len_vals = []

            for i in range(1, len(current_freq)):
                if float(current_freq[i, 1]) != 0:
                    if (float(current_freq[i, 1])/2) >= float(value) and rc_met is False:
                        
                        plt.axvline(x=float(current_freq[i, 0]), color=rc_colors[value], linestyle='dashed')
                        time_vals.append(float(current_freq[i, 0]))
                        jet_len_vals.append(float(current_freq[i, 1]))
                        rc_met = True
                    else:
                        time_vals.append(float(current_freq[i, 0]))
                        jet_len_vals.append(float(current_freq[i, 1]))
            
            plt.plot(time_vals, jet_len_vals, label="rc{}".format(str(value)), linewidth=3)
        
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Time (Myr)", fontsize=14)
plt.ylabel("Jet Length (kpc)", fontsize=14)
plt.title("Jet Lengths for Varied Densities\nL438, 30MHz", fontsize=18)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc=2, prop={'size': 10})
plt.show()
plt.savefig('Jet_Lengths_vs_Time.png')

# %%
plt.rcParams["figure.figsize"] = (6,5)

rc_colors = {3:"b", 10:"orange", 30:"green", 100:"red"}
rc_vals2 = [3, 30, 100]
for value in rc_vals2:

        with open("data_table_rc{}.npy".format(str(value)), "rb") as open_file:
            current_freq = np.load(open_file)
            if value == 3:
                current_freq[6, 3] = 0
            time_vals = []
            lobe_vals = []

            for i in range(1, len(current_freq)):
                lobe_dist = float(current_freq[i, 3])
                if lobe_dist != 0:
                    time_vals.append(float(current_freq[i, 0]))
                    lobe_vals.append(lobe_dist)

                    
                    
                prev_time = float(current_freq[i, 0])
                prev_lobe = lobe_dist
                    

            
            plt.plot(time_vals, lobe_vals, label="rc{}".format(str(value)), linewidth=3)
        
#plt.xscale("log")
#plt.yscale("log")
plt.xlabel("Time (Myr)", fontsize=14)
plt.ylabel("Jet Length (kpc)", fontsize=14)
plt.title("Jet Lengths for Varied Densities\nL438, 30MHz", fontsize=18)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc=2, prop={'size': 10})
plt.show()
plt.savefig('Jet_Lengths_vs_Time.png')
